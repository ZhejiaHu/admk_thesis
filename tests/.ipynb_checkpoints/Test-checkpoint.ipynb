# %%
import warnings
warnings.filterwarnings("ignore")
from test_multicommodity import test_main, create_forcing, plot_result
from mcopt_misc import plot_network, run_mcopt
import sys
sys.path.append('../src/')
import numpy as np
from mcopt import McOpt, paris_topology
from typing import Dict, List, Tuple
import networkx as nx
import matplotlib.pyplot as plt

# %% [markdown]
# #### Compare With McOpt

# %%
def constrcut_mcopt(beta: float=1.0, method="paris"):
    method, coupling, museed, pflux, rho = method, "l1", 0, beta, 0.0   
    time_step, tot_time, relax_linsys, tau_cond_dyn, tau_cost_dyn = 0.5, 10000, 1.0e-5, 1.0e-1, 1.0e-1
    tau_cond_opt, tau_cost_opt = 1.0e-1, 1.0e-1
    VERBOSE = False
    mcopt = McOpt(method, coupling, museed, pflux, VERBOSE, rho, relax_linsys, tau_cond_dyn, tau_cost_dyn, time_step, tot_time, tau_cond_opt, tau_cost_opt)
    mcopt.ot_setup()
    return mcopt

# %%
def compare_mcopt_admk(beta: float=1.0, method="paris"):
    mcopt = constrcut_mcopt(beta=beta, method=method)
    forcing, conductivity_mcopt = run_mcopt(mcopt)
    topo, weights, forcing_ = mcopt.export_setup()
    potentials, conductivity_admk, potentials_admk = test_main(topo.copy(), weights, len(forcing_[0]), forcing_, beta=beta, max_iter=25)
    plot_network(mcopt.g, forcing, conductivity_mcopt, conductivity_admk)
    print(conductivity_admk[0])
    return mcopt.g, forcing_

# %%
graph, forcing = compare_mcopt_admk(1, "synth")
# Out:
# * graph topology construction
# * running [dynamics]
# 	convergence achieved [dynamics]
# * export fluxes
# * export cost
# init signature: (self, tol_optimization=0.001, tol_constraint=1e-08, method='explicit_tdens', max_iter=200, max_restart=5, method_ctrl=None, verbose=0, log=0, log_file='admk.log', beta=1, log_print: bool = True)
# ierr=0 avg_it=0010 max(res)=7.4e-09 max(pres)=6.4e-07
#    1.31e+01<=UPDATE<=2.04e+03, deltat=1.96e-03
# ierr=0 avg_it=0010 max(res)=9.9e-09 max(pres)=9.6e-07
# it=1 var=1.87e+02
#    8.75e+00<=UPDATE<=9.64e+02, deltat=2.01e-02
# ierr=0 avg_it=0012 max(res)=8.7e-09 max(pres)=7.5e-07
# it=2 var=3.52e+01
#    1.75e+00<=UPDATE<=2.60e+02, deltat=1.00e-01
# ierr=0 avg_it=0012 max(res)=9.6e-09 max(pres)=6.6e-07
# it=3 var=5.36e+00
#    -1.18e+00<=UPDATE<=9.83e+01, deltat=1.00e-01
# ierr=0 avg_it=0011 max(res)=9.7e-09 max(pres)=8.1e-07
# it=4 var=1.65e+00
#    -1.63e+00<=UPDATE<=6.69e+01, deltat=1.00e-01
# ierr=0 avg_it=0011 max(res)=8.5e-09 max(pres)=7.9e-07
# it=5 var=1.02e+00
#    -1.76e+00<=UPDATE<=4.92e+01, deltat=1.00e-01
# ierr=0 avg_it=0011 max(res)=9.1e-09 max(pres)=8.5e-07
# it=6 var=7.04e-01
#    -1.84e+00<=UPDATE<=3.75e+01, deltat=1.00e-01
# ierr=0 avg_it=0011 max(res)=8.8e-09 max(pres)=7.1e-07
# it=7 var=5.16e-01
#    -2.00e+00<=UPDATE<=2.93e+01, deltat=1.00e-01
# ierr=0 avg_it=0010 max(res)=9.5e-09 max(pres)=8.1e-07
# it=8 var=3.93e-01
#    -2.05e+00<=UPDATE<=2.32e+01, deltat=1.00e-01
# ierr=0 avg_it=0010 max(res)=8.7e-09 max(pres)=6.1e-07
# it=9 var=3.07e-01
#    -2.03e+00<=UPDATE<=1.87e+01, deltat=1.00e-01
# ierr=0 avg_it=0010 max(res)=9.5e-09 max(pres)=4.9e-07
# it=10 var=2.46e-01
#    -2.07e+00<=UPDATE<=1.52e+01, deltat=1.00e-01
# ierr=0 avg_it=0010 max(res)=9.8e-09 max(pres)=5.2e-07
# it=11 var=2.00e-01
#    -2.15e+00<=UPDATE<=1.27e+01, deltat=1.00e-01
# ierr=0 avg_it=0010 max(res)=9.8e-09 max(pres)=6.7e-07
# it=12 var=1.66e-01
#    -2.19e+00<=UPDATE<=1.12e+01, deltat=1.00e-01
# ierr=0 avg_it=0010 max(res)=7.9e-09 max(pres)=4.7e-07
# it=13 var=1.40e-01
#    -2.20e+00<=UPDATE<=1.03e+01, deltat=1.00e-01
# ierr=0 avg_it=0010 max(res)=9.9e-09 max(pres)=5.7e-07
# it=14 var=1.19e-01
#    -2.18e+00<=UPDATE<=9.54e+00, deltat=1.00e-01
# ierr=0 avg_it=0010 max(res)=9.6e-09 max(pres)=8.5e-07
# it=15 var=1.03e-01
#    -2.15e+00<=UPDATE<=8.85e+00, deltat=1.00e-01
# ierr=0 avg_it=0010 max(res)=1.0e-08 max(pres)=7.9e-07
# it=16 var=9.05e-02
#    -2.12e+00<=UPDATE<=8.24e+00, deltat=1.00e-01
# ierr=0 avg_it=0010 max(res)=9.3e-09 max(pres)=8.9e-07
# it=17 var=8.03e-02
#    -2.10e+00<=UPDATE<=7.69e+00, deltat=1.00e-01
# ierr=0 avg_it=0010 max(res)=9.2e-09 max(pres)=6.5e-07
# it=18 var=7.20e-02
#    -2.06e+00<=UPDATE<=7.20e+00, deltat=1.00e-01
# ierr=0 avg_it=0010 max(res)=9.8e-09 max(pres)=7.9e-07
# it=19 var=6.52e-02
#    -2.02e+00<=UPDATE<=6.74e+00, deltat=1.00e-01
# ierr=0 avg_it=0009 max(res)=9.8e-09 max(pres)=9.2e-07
# it=20 var=5.96e-02
#    -1.98e+00<=UPDATE<=6.33e+00, deltat=1.00e-01
# ierr=0 avg_it=0010 max(res)=9.9e-09 max(pres)=9.0e-07
# it=21 var=5.49e-02
#    -1.93e+00<=UPDATE<=5.95e+00, deltat=1.00e-01
# ierr=0 avg_it=0009 max(res)=9.7e-09 max(pres)=9.1e-07
# it=22 var=5.09e-02
#    -1.88e+00<=UPDATE<=5.60e+00, deltat=1.00e-01
# ierr=0 avg_it=0009 max(res)=9.3e-09 max(pres)=8.5e-07
# it=23 var=4.74e-02
#    -1.83e+00<=UPDATE<=5.27e+00, deltat=1.00e-01
# ierr=0 avg_it=0009 max(res)=9.0e-09 max(pres)=8.2e-07
# it=24 var=4.45e-02
#    -1.78e+00<=UPDATE<=4.96e+00, deltat=1.00e-01
# ierr=0 avg_it=0009 max(res)=9.5e-09 max(pres)=8.0e-07
# it=25 var=4.19e-02
# tdens_admk_: [ 7.85302894 29.86656274 44.87686292  3.85232377 52.8222392   1.84778063
#  20.55041043  6.63041964  7.16507627 61.44429694 29.90098723 59.78649803
#  25.83434613  3.76852481 55.54791346 15.97953585 51.38401258 61.34183498
#  34.951595    0.71977223 20.78484098 41.94030353 66.23189659 64.32780453
#   2.51907016  3.57968482  4.31684125  1.172828   26.53102898  1.29003556
#  23.91353699 49.37471252 19.11745335 21.69326931  5.55819183 10.51507476
#  23.81233708 64.36389967  2.72753567 33.64565499  1.42337147 85.13048856
#   0.98788729 62.78283303  3.0239989   5.45295097  5.51451835 53.76029101
#  16.39328442 46.84472746  3.28227479  7.53179091  2.46683152 92.59274385
#  56.13839667 17.73584975 32.72861487 18.77353776  5.57482995 16.81224658
#   2.3875713   0.83595927  1.36245488 53.314162    5.91919373 15.56775592
#   2.26739574 37.5101742   0.68269309 26.53993394  3.63069466 29.01917867
#   1.41371379 11.59163344 40.55717955  4.20960549]
# 7.853028942043245

# %% [markdown]
# ###### Apply Fine-Grain Method On Waxman Graph

# %%
def discretize(graph: nx.Graph, forcing: List[np.ndarray], mesh_size=30, beta=1, max_iter=20):
    num_commodity = len(graph.nodes)
    def grid_coord_idx(coord: Tuple[int, int]): 
        return coord[0] * mesh_size + coord[1]
    
    mesh = nx.grid_2d_graph(mesh_size, mesh_size)
    forcing_grid = [np.zeros(num_commodity) for _ in range(mesh_size * mesh_size)]
    for node in graph.nodes:
        cur_pos_on_grid: Tuple[int, int] = (round(graph.nodes[node]["pos"][0] * mesh_size), round(graph.nodes[node]["pos"][1] * mesh_size))
        print(f"Original pos: {graph.nodes[node]['pos']} | Pos on grid: {cur_pos_on_grid}")
        cur_pos_idx = grid_coord_idx(cur_pos_on_grid)
        for comm in range(num_commodity):
            forcing_grid[cur_pos_idx][comm] += forcing[node][comm]
    for node in mesh.nodes():
        mesh.nodes[node]["amplitude"] = np.linalg.norm(forcing_grid[grid_coord_idx(node)])
    edge_lists = np.array([list((grid_coord_idx(e[0]), grid_coord_idx(e[1]))) for e in mesh.edges()])
    weights = np.ones_like(edge_lists[:,0])
    potentials, conductivity_admk, potentials_admk = test_main(edge_lists, weights, num_commodity, forcing_grid, beta=beta, max_iter=max_iter)
    plt.show()
    pos = {n: (n[0], n[1]) for n in mesh.nodes()}
    nx.draw_networkx_edges(mesh, pos=pos, width=np.array(conductivity_admk) * 0.1,  edge_color='C0', style='solid')
    amps = [mesh.nodes[n]['amplitude']  for n in mesh.nodes()]
    nx.draw_networkx_nodes(mesh, pos=pos, node_size=amps, node_color='orange')
    plt.show()
    return mesh, conductivity_admk

# %% [markdown]
# The scale of the `forcing` needs to be altered for different methods and topology, here we set it to `1e5`, which <ins>might not work</ins> for alternative problems (optimization might not run properly).

# %%
discretize(graph, forcing)
# Out:
# Original pos: (0.8444218515250481, 0.7579544029403025) | Pos on grid: (25, 23)
# Original pos: (0.420571580830845, 0.25891675029296335) | Pos on grid: (13, 8)
# Original pos: (0.5112747213686085, 0.4049341374504143) | Pos on grid: (15, 12)
# Original pos: (0.7837985890347726, 0.30331272607892745) | Pos on grid: (24, 9)
# Original pos: (0.4765969541523558, 0.5833820394550312) | Pos on grid: (14, 18)
# Original pos: (0.9081128851953352, 0.5046868558173903) | Pos on grid: (27, 15)
# Original pos: (0.28183784439970383, 0.7558042041572239) | Pos on grid: (8, 23)
# Original pos: (0.6183689966753316, 0.25050634136244054) | Pos on grid: (19, 8)
# Original pos: (0.9097462559682401, 0.9827854760376531) | Pos on grid: (27, 29)
# Original pos: (0.8102172359965896, 0.9021659504395827) | Pos on grid: (24, 27)
# Original pos: (0.3101475693193326, 0.7298317482601286) | Pos on grid: (9, 22)
# Original pos: (0.8988382879679935, 0.6839839319154413) | Pos on grid: (27, 21)
# Original pos: (0.47214271545271336, 0.1007012080683658) | Pos on grid: (14, 3)
# Original pos: (0.4341718354537837, 0.6108869734438016) | Pos on grid: (13, 18)
# Original pos: (0.9130110532378982, 0.9666063677707588) | Pos on grid: (27, 29)
# Original pos: (0.47700977655271704, 0.8653099277716401) | Pos on grid: (14, 26)
# Original pos: (0.2604923103919594, 0.8050278270130223) | Pos on grid: (8, 24)
# Original pos: (0.5486993038355893, 0.014041700164018955) | Pos on grid: (16, 0)
# Original pos: (0.7197046864039541, 0.39882354222426875) | Pos on grid: (22, 12)
# Original pos: (0.824844977148233, 0.6681532012318508) | Pos on grid: (25, 20)
# Original pos: (0.0011428193144282783, 0.49357786646532464) | Pos on grid: (0, 15)
# Original pos: (0.8676027754927809, 0.24391087688713198) | Pos on grid: (26, 7)
# Original pos: (0.32520436274739006, 0.8704712321086546) | Pos on grid: (10, 26)
# Original pos: (0.19106709150239054, 0.5675107406206719) | Pos on grid: (6, 17)
# Original pos: (0.23861592861522019, 0.9675402502901433) | Pos on grid: (7, 29)
# Original pos: (0.80317946927987, 0.44796957143557037) | Pos on grid: (24, 13)
# Original pos: (0.08044581855253541, 0.32005460467254576) | Pos on grid: (2, 10)
# Original pos: (0.5079406425205739, 0.9328338242269067) | Pos on grid: (15, 28)
# Original pos: (0.10905784593110368, 0.5512672460905512) | Pos on grid: (3, 17)
# Original pos: (0.7065614098668896, 0.5474409113284238) | Pos on grid: (21, 16)
# init signature: (self, tol_optimization=0.001, tol_constraint=1e-08, method='explicit_tdens', max_iter=200, max_restart=5, method_ctrl=None, verbose=0, log=0, log_file='admk.log', beta=1, log_print: bool = True)
# ierr=0 avg_it=0024 max(res)=9.7e-09 max(pres)=9.6e-07
#    -1.94e+00<=UPDATE<=5.36e+02, deltat=7.47e-03
# ierr=0 avg_it=0023 max(res)=9.9e-09 max(pres)=8.4e-07
# it=1 var=2.46e+01
#    -1.93e+00<=UPDATE<=2.29e+02, deltat=7.22e-02
# ierr=0 avg_it=0025 max(res)=9.8e-09 max(pres)=8.8e-07
# it=2 var=7.72e+00
#    -1.80e+00<=UPDATE<=5.60e+01, deltat=1.00e-01
# ierr=0 avg_it=0024 max(res)=9.8e-09 max(pres)=9.6e-07
# it=3 var=2.04e+00
#    -1.62e+00<=UPDATE<=3.95e+01, deltat=1.00e-01
# ierr=0 avg_it=0023 max(res)=9.9e-09 max(pres)=1.3e-06
# it=4 var=1.20e+00
#    -1.45e+00<=UPDATE<=3.01e+01, deltat=1.00e-01
# ierr=0 avg_it=0023 max(res)=1.0e-08 max(pres)=1.2e-06
# it=5 var=8.27e-01
#    -1.30e+00<=UPDATE<=2.38e+01, deltat=1.00e-01
# ierr=0 avg_it=0023 max(res)=9.9e-09 max(pres)=1.2e-06
# it=6 var=6.15e-01
#    -1.17e+00<=UPDATE<=1.94e+01, deltat=1.00e-01
# ierr=0 avg_it=0022 max(res)=9.3e-09 max(pres)=1.2e-06
# it=7 var=4.81e-01
#    -1.31e+00<=UPDATE<=1.60e+01, deltat=1.00e-01
# ierr=0 avg_it=0022 max(res)=1.0e-08 max(pres)=1.0e-06
# it=8 var=3.90e-01
#    -1.39e+00<=UPDATE<=1.38e+01, deltat=1.00e-01
# ierr=0 avg_it=0022 max(res)=9.5e-09 max(pres)=8.2e-07
# it=9 var=3.25e-01
#    -1.42e+00<=UPDATE<=1.21e+01, deltat=1.00e-01
# ierr=0 avg_it=0022 max(res)=9.6e-09 max(pres)=1.1e-06
# it=10 var=2.78e-01
#    -1.47e+00<=UPDATE<=1.09e+01, deltat=1.00e-01
# ierr=0 avg_it=0021 max(res)=9.6e-09 max(pres)=1.3e-06
# it=11 var=2.43e-01
#    -1.62e+00<=UPDATE<=9.99e+00, deltat=1.00e-01
# ierr=0 avg_it=0021 max(res)=9.8e-09 max(pres)=1.2e-06
# it=12 var=2.16e-01
#    -1.71e+00<=UPDATE<=9.24e+00, deltat=1.00e-01
# ierr=0 avg_it=0021 max(res)=9.9e-09 max(pres)=1.1e-06
# it=13 var=1.95e-01
#    -1.75e+00<=UPDATE<=8.60e+00, deltat=1.00e-01
# ierr=0 avg_it=0021 max(res)=9.7e-09 max(pres)=1.1e-06
# it=14 var=1.78e-01
#    -1.77e+00<=UPDATE<=8.06e+00, deltat=1.00e-01
# ierr=0 avg_it=0021 max(res)=9.9e-09 max(pres)=1.1e-06
# it=15 var=1.64e-01
#    -1.76e+00<=UPDATE<=7.60e+00, deltat=1.00e-01
# ierr=0 avg_it=0021 max(res)=9.7e-09 max(pres)=1.1e-06
# it=16 var=1.53e-01
#    -1.74e+00<=UPDATE<=7.21e+00, deltat=1.00e-01
# ierr=0 avg_it=0021 max(res)=9.7e-09 max(pres)=1.0e-06
# it=17 var=1.44e-01
#    -1.74e+00<=UPDATE<=6.88e+00, deltat=1.00e-01
# ierr=0 avg_it=0021 max(res)=9.9e-09 max(pres)=9.7e-07
# it=18 var=1.35e-01
#    -1.82e+00<=UPDATE<=6.57e+00, deltat=1.00e-01
# ierr=0 avg_it=0021 max(res)=9.9e-09 max(pres)=1.3e-06
# it=19 var=1.28e-01
#    -1.88e+00<=UPDATE<=6.30e+00, deltat=1.00e-01
# ierr=0 avg_it=0021 max(res)=1.0e-08 max(pres)=1.2e-06
# it=20 var=1.22e-01
# (<networkx.classes.graph.Graph at 0x79f0f1139750>,
#  array([2.66754959, 0.41682848, 3.27926076, ..., 8.60830813, 1.04014277,
#         0.702827  ], shape=(1740,)))

# %% [markdown]
# We set beta to a different value to observe if the generated result has a different pattern.

# %%
discretize(graph, forcing, beta=0.1)
# Out:
# Original pos: (0.8444218515250481, 0.7579544029403025) | Pos on grid: (25, 23)
# Original pos: (0.420571580830845, 0.25891675029296335) | Pos on grid: (13, 8)
# Original pos: (0.5112747213686085, 0.4049341374504143) | Pos on grid: (15, 12)
# Original pos: (0.7837985890347726, 0.30331272607892745) | Pos on grid: (24, 9)
# Original pos: (0.4765969541523558, 0.5833820394550312) | Pos on grid: (14, 18)
# Original pos: (0.9081128851953352, 0.5046868558173903) | Pos on grid: (27, 15)
# Original pos: (0.28183784439970383, 0.7558042041572239) | Pos on grid: (8, 23)
# Original pos: (0.6183689966753316, 0.25050634136244054) | Pos on grid: (19, 8)
# Original pos: (0.9097462559682401, 0.9827854760376531) | Pos on grid: (27, 29)
# Original pos: (0.8102172359965896, 0.9021659504395827) | Pos on grid: (24, 27)
# Original pos: (0.3101475693193326, 0.7298317482601286) | Pos on grid: (9, 22)
# Original pos: (0.8988382879679935, 0.6839839319154413) | Pos on grid: (27, 21)
# Original pos: (0.47214271545271336, 0.1007012080683658) | Pos on grid: (14, 3)
# Original pos: (0.4341718354537837, 0.6108869734438016) | Pos on grid: (13, 18)
# Original pos: (0.9130110532378982, 0.9666063677707588) | Pos on grid: (27, 29)
# Original pos: (0.47700977655271704, 0.8653099277716401) | Pos on grid: (14, 26)
# Original pos: (0.2604923103919594, 0.8050278270130223) | Pos on grid: (8, 24)
# Original pos: (0.5486993038355893, 0.014041700164018955) | Pos on grid: (16, 0)
# Original pos: (0.7197046864039541, 0.39882354222426875) | Pos on grid: (22, 12)
# Original pos: (0.824844977148233, 0.6681532012318508) | Pos on grid: (25, 20)
# Original pos: (0.0011428193144282783, 0.49357786646532464) | Pos on grid: (0, 15)
# Original pos: (0.8676027754927809, 0.24391087688713198) | Pos on grid: (26, 7)
# Original pos: (0.32520436274739006, 0.8704712321086546) | Pos on grid: (10, 26)
# Original pos: (0.19106709150239054, 0.5675107406206719) | Pos on grid: (6, 17)
# Original pos: (0.23861592861522019, 0.9675402502901433) | Pos on grid: (7, 29)
# Original pos: (0.80317946927987, 0.44796957143557037) | Pos on grid: (24, 13)
# Original pos: (0.08044581855253541, 0.32005460467254576) | Pos on grid: (2, 10)
# Original pos: (0.5079406425205739, 0.9328338242269067) | Pos on grid: (15, 28)
# Original pos: (0.10905784593110368, 0.5512672460905512) | Pos on grid: (3, 17)
# Original pos: (0.7065614098668896, 0.5474409113284238) | Pos on grid: (21, 16)
# init signature: (self, tol_optimization=0.001, tol_constraint=1e-08, method='explicit_tdens', max_iter=200, max_restart=5, method_ctrl=None, verbose=0, log=0, log_file='admk.log', beta=1, log_print: bool = True)
# ierr=0 avg_it=0024 max(res)=9.7e-09 max(pres)=9.6e-07
#    -1.97e+00<=UPDATE<=2.86e+02, deltat=7.47e-03
# ierr=0 avg_it=0022 max(res)=8.9e-09 max(pres)=1.2e-06
# it=1 var=1.37e+01
#    -1.95e+00<=UPDATE<=8.77e+01, deltat=4.49e-02
# ierr=0 avg_it=0024 max(res)=9.7e-09 max(pres)=1.2e-06
# it=2 var=5.83e+00
#    -1.87e+00<=UPDATE<=2.07e+01, deltat=1.00e-01
# ierr=0 avg_it=0023 max(res)=1.0e-08 max(pres)=1.3e-06
# it=3 var=1.75e+00
#    -1.68e+00<=UPDATE<=9.22e+00, deltat=1.00e-01
# ierr=0 avg_it=0022 max(res)=9.7e-09 max(pres)=1.1e-06
# it=4 var=7.28e-01
#    -1.50e+00<=UPDATE<=5.61e+00, deltat=1.00e-01
# ierr=0 avg_it=0022 max(res)=9.0e-09 max(pres)=8.1e-07
# it=5 var=4.38e-01
#    -1.34e+00<=UPDATE<=3.72e+00, deltat=1.00e-01
# ierr=0 avg_it=0021 max(res)=9.7e-09 max(pres)=1.0e-06
# it=6 var=2.95e-01
#    -1.20e+00<=UPDATE<=2.57e+00, deltat=1.00e-01
# ierr=0 avg_it=0021 max(res)=9.9e-09 max(pres)=1.1e-06
# it=7 var=2.13e-01
#    -1.07e+00<=UPDATE<=1.83e+00, deltat=1.00e-01
# ierr=0 avg_it=0021 max(res)=9.8e-09 max(pres)=1.0e-06
# it=8 var=1.60e-01
#    -9.45e-01<=UPDATE<=1.46e+00, deltat=1.00e-01
# ierr=0 avg_it=0020 max(res)=9.8e-09 max(pres)=1.2e-06
# it=9 var=1.25e-01
#    -8.34e-01<=UPDATE<=1.20e+00, deltat=1.00e-01
# ierr=0 avg_it=0020 max(res)=9.9e-09 max(pres)=1.0e-06
# it=10 var=1.01e-01
#    -7.32e-01<=UPDATE<=9.97e-01, deltat=1.00e-01
# ierr=0 avg_it=0019 max(res)=9.9e-09 max(pres)=1.2e-06
# it=11 var=8.29e-02
#    -6.39e-01<=UPDATE<=8.39e-01, deltat=1.00e-01
# ierr=0 avg_it=0019 max(res)=9.1e-09 max(pres)=1.1e-06
# it=12 var=6.92e-02
#    -5.52e-01<=UPDATE<=7.13e-01, deltat=1.00e-01
# ierr=0 avg_it=0019 max(res)=9.9e-09 max(pres)=1.3e-06
# it=13 var=5.84e-02
#    -4.73e-01<=UPDATE<=6.09e-01, deltat=1.00e-01
# ierr=0 avg_it=0019 max(res)=9.6e-09 max(pres)=1.2e-06
# it=14 var=4.98e-02
#    -4.01e-01<=UPDATE<=5.24e-01, deltat=1.00e-01
# ierr=0 avg_it=0018 max(res)=9.7e-09 max(pres)=1.1e-06
# it=15 var=4.27e-02
#    -3.36e-01<=UPDATE<=4.53e-01, deltat=1.00e-01
# ierr=0 avg_it=0018 max(res)=9.9e-09 max(pres)=1.1e-06
# it=16 var=3.69e-02
#    -2.87e-01<=UPDATE<=3.93e-01, deltat=1.00e-01
# ierr=0 avg_it=0018 max(res)=9.8e-09 max(pres)=1.0e-06
# it=17 var=3.20e-02
#    -2.56e-01<=UPDATE<=3.42e-01, deltat=1.00e-01
# ierr=0 avg_it=0018 max(res)=9.5e-09 max(pres)=1.2e-06
# it=18 var=2.78e-02
#    -2.28e-01<=UPDATE<=2.99e-01, deltat=1.00e-01
# ierr=0 avg_it=0017 max(res)=9.8e-09 max(pres)=1.1e-06
# it=19 var=2.43e-02
#    -2.03e-01<=UPDATE<=2.61e-01, deltat=1.00e-01
# ierr=0 avg_it=0017 max(res)=9.7e-09 max(pres)=1.0e-06
# it=20 var=2.12e-02
# (<networkx.classes.graph.Graph at 0x79f0f0afbb80>,
#  array([1.9968927 , 0.57607933, 2.21818228, ..., 5.36669247, 1.09023898,
#         0.97336291], shape=(1740,)))

# %%
discretize(graph, forcing, beta=1.5)
# Out:
# Original pos: (0.8444218515250481, 0.7579544029403025) | Pos on grid: (25, 23)
# Original pos: (0.420571580830845, 0.25891675029296335) | Pos on grid: (13, 8)
# Original pos: (0.5112747213686085, 0.4049341374504143) | Pos on grid: (15, 12)
# Original pos: (0.7837985890347726, 0.30331272607892745) | Pos on grid: (24, 9)
# Original pos: (0.4765969541523558, 0.5833820394550312) | Pos on grid: (14, 18)
# Original pos: (0.9081128851953352, 0.5046868558173903) | Pos on grid: (27, 15)
# Original pos: (0.28183784439970383, 0.7558042041572239) | Pos on grid: (8, 23)
# Original pos: (0.6183689966753316, 0.25050634136244054) | Pos on grid: (19, 8)
# Original pos: (0.9097462559682401, 0.9827854760376531) | Pos on grid: (27, 29)
# Original pos: (0.8102172359965896, 0.9021659504395827) | Pos on grid: (24, 27)
# Original pos: (0.3101475693193326, 0.7298317482601286) | Pos on grid: (9, 22)
# Original pos: (0.8988382879679935, 0.6839839319154413) | Pos on grid: (27, 21)
# Original pos: (0.47214271545271336, 0.1007012080683658) | Pos on grid: (14, 3)
# Original pos: (0.4341718354537837, 0.6108869734438016) | Pos on grid: (13, 18)
# Original pos: (0.9130110532378982, 0.9666063677707588) | Pos on grid: (27, 29)
# Original pos: (0.47700977655271704, 0.8653099277716401) | Pos on grid: (14, 26)
# Original pos: (0.2604923103919594, 0.8050278270130223) | Pos on grid: (8, 24)
# Original pos: (0.5486993038355893, 0.014041700164018955) | Pos on grid: (16, 0)
# Original pos: (0.7197046864039541, 0.39882354222426875) | Pos on grid: (22, 12)
# Original pos: (0.824844977148233, 0.6681532012318508) | Pos on grid: (25, 20)
# Original pos: (0.0011428193144282783, 0.49357786646532464) | Pos on grid: (0, 15)
# Original pos: (0.8676027754927809, 0.24391087688713198) | Pos on grid: (26, 7)
# Original pos: (0.32520436274739006, 0.8704712321086546) | Pos on grid: (10, 26)
# Original pos: (0.19106709150239054, 0.5675107406206719) | Pos on grid: (6, 17)
# Original pos: (0.23861592861522019, 0.9675402502901433) | Pos on grid: (7, 29)
# Original pos: (0.80317946927987, 0.44796957143557037) | Pos on grid: (24, 13)
# Original pos: (0.08044581855253541, 0.32005460467254576) | Pos on grid: (2, 10)
# Original pos: (0.5079406425205739, 0.9328338242269067) | Pos on grid: (15, 28)
# Original pos: (0.10905784593110368, 0.5512672460905512) | Pos on grid: (3, 17)
# Original pos: (0.7065614098668896, 0.5474409113284238) | Pos on grid: (21, 16)
# init signature: (self, tol_optimization=0.001, tol_constraint=1e-08, method='explicit_tdens', max_iter=200, max_restart=5, method_ctrl=None, verbose=0, log=0, log_file='admk.log', beta=1, log_print: bool = True)
# ierr=0 avg_it=0024 max(res)=9.7e-09 max(pres)=9.6e-07
#    -1.92e+00<=UPDATE<=7.58e+02, deltat=7.47e-03
# ierr=0 avg_it=0024 max(res)=1.0e-08 max(pres)=9.8e-07
# it=1 var=3.33e+01
#    -1.91e+00<=UPDATE<=4.97e+02, deltat=1.00e-01
# ierr=0 avg_it=0027 max(res)=9.3e-09 max(pres)=7.0e-07
# it=2 var=7.61e+00
#    -1.74e+00<=UPDATE<=2.00e+02, deltat=1.00e-01
# ierr=0 avg_it=0026 max(res)=9.7e-09 max(pres)=9.1e-07
# it=3 var=2.57e+00
#    -1.58e+00<=UPDATE<=1.73e+02, deltat=1.00e-01
# ierr=0 avg_it=0025 max(res)=9.1e-09 max(pres)=9.6e-07
# it=4 var=1.80e+00
#    -2.07e+00<=UPDATE<=1.54e+02, deltat=1.00e-01
# ierr=0 avg_it=0025 max(res)=9.9e-09 max(pres)=1.2e-06
# it=5 var=1.40e+00
#    -2.78e+00<=UPDATE<=1.39e+02, deltat=1.00e-01
# ierr=0 avg_it=0025 max(res)=1.0e-08 max(pres)=1.2e-06
# it=6 var=1.15e+00
#    -3.10e+00<=UPDATE<=1.28e+02, deltat=1.00e-01
# ierr=0 avg_it=0025 max(res)=9.6e-09 max(pres)=9.0e-07
# it=7 var=9.86e-01
#    -3.85e+00<=UPDATE<=1.19e+02, deltat=1.00e-01
# ierr=0 avg_it=0025 max(res)=9.4e-09 max(pres)=9.3e-07
# it=8 var=8.65e-01
#    -4.71e+00<=UPDATE<=1.14e+02, deltat=1.00e-01
# ierr=0 avg_it=0025 max(res)=9.3e-09 max(pres)=1.1e-06
# it=9 var=7.72e-01
#    -5.78e+00<=UPDATE<=1.09e+02, deltat=1.00e-01
# ierr=0 avg_it=0025 max(res)=1.0e-08 max(pres)=1.2e-06
# it=10 var=6.97e-01
#    -9.98e+00<=UPDATE<=1.05e+02, deltat=1.00e-01
# ierr=0 avg_it=0025 max(res)=9.8e-09 max(pres)=9.7e-07
# it=11 var=6.34e-01
#    -1.33e+01<=UPDATE<=1.01e+02, deltat=1.00e-01
# ierr=0 avg_it=0025 max(res)=9.8e-09 max(pres)=1.0e-06
# it=12 var=5.81e-01
#    -1.58e+01<=UPDATE<=9.69e+01, deltat=1.00e-01
# ierr=0 avg_it=0026 max(res)=9.8e-09 max(pres)=1.1e-06
# it=13 var=5.34e-01
#    -1.77e+01<=UPDATE<=9.29e+01, deltat=1.00e-01
# ierr=0 avg_it=0026 max(res)=9.5e-09 max(pres)=1.1e-06
# it=14 var=4.94e-01
#    -1.90e+01<=UPDATE<=8.90e+01, deltat=1.00e-01
# ierr=0 avg_it=0026 max(res)=1.0e-08 max(pres)=1.1e-06
# it=15 var=4.58e-01
#    -1.98e+01<=UPDATE<=8.53e+01, deltat=1.00e-01
# ierr=0 avg_it=0026 max(res)=9.8e-09 max(pres)=1.1e-06
# it=16 var=4.27e-01
#    -2.04e+01<=UPDATE<=8.19e+01, deltat=1.00e-01
# ierr=0 avg_it=0026 max(res)=9.8e-09 max(pres)=1.3e-06
# it=17 var=3.99e-01
#    -2.06e+01<=UPDATE<=7.87e+01, deltat=1.00e-01
# ierr=0 avg_it=0037 max(res)=9.9e-09 max(pres)=1.1e-06
# it=18 var=3.74e-01
#    -2.07e+01<=UPDATE<=7.59e+01, deltat=1.00e-01
# ierr=0 avg_it=0037 max(res)=9.3e-09 max(pres)=1.2e-06
# it=19 var=3.52e-01
#    -2.05e+01<=UPDATE<=7.34e+01, deltat=1.00e-01
# ierr=0 avg_it=0037 max(res)=9.7e-09 max(pres)=1.1e-06
# it=20 var=3.33e-01
# (<networkx.classes.graph.Graph at 0x79f0f0b7ff10>,
#  array([ 3.59258057,  0.33425544,  5.05110303, ..., 12.36357381,
#          1.02582175,  0.55515257], shape=(1740,)))

# %% [markdown]
# **Conclusions**:
# 1. It seems that we need to postprocess the result generating from the mesh. For instance, we need run some <inv>pruning algorithm</inv> to remove unnecessary edges (whose conductivity is so small), while maintaining the connectivity of the graph.
# 2. Though we are not allowed to provide the edge information, but if certain amount of mass is transferred from vertex $u$ to $v$, shaall we add weights of the edge that connect the paths between $u$ and $v$.

# %% [markdown]
# #### Triangular Lattice Graph

# %%
def discretize_triangular(graph: nx.Graph, forcing: List[np.ndarray], mesh_size=27, beta=1, max_iter=20):
    X_SCALE, Y_SCALE = mesh_size - 1, (mesh_size - 1) * (np.sqrt(3) / 2)
    num_commodity = len(graph.nodes)
    mesh = nx.triangular_lattice_graph(mesh_size, mesh_size * 2)
    nodes_list = list(mesh.nodes())          
    key_to_index = {key: idx for idx, key in enumerate(nodes_list)}
    idx_to_key = {idx: key for key, idx in key_to_index.items()}
    
    def coordinate_to_key(coord):
        y = int(coord[1] / (np.sqrt(3) / 2) + 0.5)
        x = round(coord[0]) if y % 2 == 0 else round(coord[0] - 0.5)
        return (x, y)

    forcing_grid = [np.zeros(num_commodity) for _ in range(len(mesh.nodes()))]
    print(f"Size of the forcing grid is {len(forcing_grid)}")
    for node in graph.nodes:
        raw_pos = (graph.nodes[node]["pos"][0] * X_SCALE, graph.nodes[node]["pos"][1] * Y_SCALE)
        key = coordinate_to_key(raw_pos)
        index = key_to_index[key]
        for comm in range(num_commodity):
            forcing_grid[index][comm] += forcing[node][comm]
    
    for node in mesh.nodes():
        mesh.nodes[node]["amplitude"] = np.linalg.norm(forcing_grid[key_to_index[node]])
    edge_lists = np.array([list((key_to_index[e[0]], key_to_index[e[1]])) for e in mesh.edges()])
    weights = np.ones_like(edge_lists[:,0])
    potentials, conductivity_admk, potentials_admk = test_main(edge_lists, weights, num_commodity, forcing_grid, beta=beta, max_iter=max_iter)
    # for cpot in potentials: print(cpot[0:20])
    plt.show()
    pos = {n: (n[0], n[1]) for n in mesh.nodes()}
    nx.draw_networkx_edges(mesh, pos=pos, width=np.array(conductivity_admk) * 0.2,  edge_color='C0', style='solid')
    amps = [mesh.nodes[n]['amplitude']  for n in mesh.nodes()]
    nx.draw_networkx_nodes(mesh, pos=pos, node_size=amps, node_color='orange')
    plt.show()
    return mesh, conductivity_admk

# %%
for max_iter in range(1, 7):
    discretize_triangular(graph, forcing, max_iter=max_iter, beta=1)
# Out:
# Size of the forcing grid is 784
# init signature: (self, tol_optimization=0.001, tol_constraint=1e-08, method='explicit_tdens', max_iter=200, max_restart=5, method_ctrl=None, verbose=0, log=0, log_file='admk.log', beta=1, log_print: bool = True)
# ierr=0 avg_it=0033 max(res)=9.9e-09 max(pres)=1.1e-06
#    -2.00e+00<=UPDATE<=5.40e+02, deltat=7.41e-03
# ierr=0 avg_it=0030 max(res)=9.5e-09 max(pres)=1.1e-06
# it=1 var=1.46e+01
# Size of the forcing grid is 784
# init signature: (self, tol_optimization=0.001, tol_constraint=1e-08, method='explicit_tdens', max_iter=200, max_restart=5, method_ctrl=None, verbose=0, log=0, log_file='admk.log', beta=1, log_print: bool = True)
# ierr=0 avg_it=0033 max(res)=9.9e-09 max(pres)=1.1e-06
#    -2.00e+00<=UPDATE<=5.40e+02, deltat=7.41e-03
# ierr=0 avg_it=0030 max(res)=9.5e-09 max(pres)=1.1e-06
# it=1 var=1.46e+01
#    -1.98e+00<=UPDATE<=1.90e+02, deltat=7.98e-02
# ierr=0 avg_it=0034 max(res)=9.3e-09 max(pres)=9.8e-07
# it=2 var=5.99e+00
# Size of the forcing grid is 784
# init signature: (self, tol_optimization=0.001, tol_constraint=1e-08, method='explicit_tdens', max_iter=200, max_restart=5, method_ctrl=None, verbose=0, log=0, log_file='admk.log', beta=1, log_print: bool = True)
# ierr=0 avg_it=0033 max(res)=9.9e-09 max(pres)=1.1e-06
#    -2.00e+00<=UPDATE<=5.40e+02, deltat=7.41e-03
# ierr=0 avg_it=0030 max(res)=9.5e-09 max(pres)=1.1e-06
# it=1 var=1.46e+01
#    -1.98e+00<=UPDATE<=1.90e+02, deltat=7.98e-02
# ierr=0 avg_it=0034 max(res)=9.3e-09 max(pres)=9.8e-07
# it=2 var=5.99e+00
#    -1.95e+00<=UPDATE<=4.33e+01, deltat=1.00e-01
# ierr=0 avg_it=0032 max(res)=1.0e-08 max(pres)=9.1e-07
# it=3 var=1.80e+00
# Size of the forcing grid is 784
# init signature: (self, tol_optimization=0.001, tol_constraint=1e-08, method='explicit_tdens', max_iter=200, max_restart=5, method_ctrl=None, verbose=0, log=0, log_file='admk.log', beta=1, log_print: bool = True)
# ierr=0 avg_it=0033 max(res)=9.9e-09 max(pres)=1.1e-06
#    -2.00e+00<=UPDATE<=5.40e+02, deltat=7.41e-03
# ierr=0 avg_it=0030 max(res)=9.5e-09 max(pres)=1.1e-06
# it=1 var=1.46e+01
#    -1.98e+00<=UPDATE<=1.90e+02, deltat=7.98e-02
# ierr=0 avg_it=0034 max(res)=9.3e-09 max(pres)=9.8e-07
# it=2 var=5.99e+00
#    -1.95e+00<=UPDATE<=4.33e+01, deltat=1.00e-01
# ierr=0 avg_it=0032 max(res)=1.0e-08 max(pres)=9.1e-07
# it=3 var=1.80e+00
#    -2.08e+00<=UPDATE<=3.23e+01, deltat=1.00e-01
# ierr=0 avg_it=0031 max(res)=9.7e-09 max(pres)=8.8e-07
# it=4 var=1.14e+00
# Size of the forcing grid is 784
# init signature: (self, tol_optimization=0.001, tol_constraint=1e-08, method='explicit_tdens', max_iter=200, max_restart=5, method_ctrl=None, verbose=0, log=0, log_file='admk.log', beta=1, log_print: bool = True)
# ierr=0 avg_it=0033 max(res)=9.9e-09 max(pres)=1.1e-06
#    -2.00e+00<=UPDATE<=5.40e+02, deltat=7.41e-03
# ierr=0 avg_it=0030 max(res)=9.5e-09 max(pres)=1.1e-06
# it=1 var=1.46e+01
#    -1.98e+00<=UPDATE<=1.90e+02, deltat=7.98e-02
# ierr=0 avg_it=0034 max(res)=9.3e-09 max(pres)=9.8e-07
# it=2 var=5.99e+00
#    -1.95e+00<=UPDATE<=4.33e+01, deltat=1.00e-01
# ierr=0 avg_it=0032 max(res)=1.0e-08 max(pres)=9.1e-07
# it=3 var=1.80e+00
#    -2.08e+00<=UPDATE<=3.23e+01, deltat=1.00e-01
# ierr=0 avg_it=0031 max(res)=9.7e-09 max(pres)=8.8e-07
# it=4 var=1.14e+00
#    -2.00e+00<=UPDATE<=2.61e+01, deltat=1.00e-01
# ierr=0 avg_it=0031 max(res)=9.3e-09 max(pres)=9.8e-07
# it=5 var=8.22e-01
# Size of the forcing grid is 784
# init signature: (self, tol_optimization=0.001, tol_constraint=1e-08, method='explicit_tdens', max_iter=200, max_restart=5, method_ctrl=None, verbose=0, log=0, log_file='admk.log', beta=1, log_print: bool = True)
# ierr=0 avg_it=0033 max(res)=9.9e-09 max(pres)=1.1e-06
#    -2.00e+00<=UPDATE<=5.40e+02, deltat=7.41e-03
# ierr=0 avg_it=0030 max(res)=9.5e-09 max(pres)=1.1e-06
# it=1 var=1.46e+01
#    -1.98e+00<=UPDATE<=1.90e+02, deltat=7.98e-02
# ierr=0 avg_it=0034 max(res)=9.3e-09 max(pres)=9.8e-07
# it=2 var=5.99e+00
#    -1.95e+00<=UPDATE<=4.33e+01, deltat=1.00e-01
# ierr=0 avg_it=0032 max(res)=1.0e-08 max(pres)=9.1e-07
# it=3 var=1.80e+00
#    -2.08e+00<=UPDATE<=3.23e+01, deltat=1.00e-01
# ierr=0 avg_it=0031 max(res)=9.7e-09 max(pres)=8.8e-07
# it=4 var=1.14e+00
#    -2.00e+00<=UPDATE<=2.61e+01, deltat=1.00e-01
# ierr=0 avg_it=0031 max(res)=9.3e-09 max(pres)=9.8e-07
# it=5 var=8.22e-01
#    -1.87e+00<=UPDATE<=2.18e+01, deltat=1.00e-01
# ierr=0 avg_it=0030 max(res)=9.5e-09 max(pres)=9.2e-07
# it=6 var=6.31e-01

# %%
discretize_triangular(graph, forcing, beta=1.2)
# Out:
# Size of the forcing grid is 784
# init signature: (self, tol_optimization=0.001, tol_constraint=1e-08, method='explicit_tdens', max_iter=200, max_restart=5, method_ctrl=None, verbose=0, log=0, log_file='admk.log', beta=1, log_print: bool = True)
# ierr=0 avg_it=0033 max(res)=9.9e-09 max(pres)=1.1e-06
#    -1.99e+00<=UPDATE<=6.20e+02, deltat=7.41e-03
# ierr=0 avg_it=0031 max(res)=9.8e-09 max(pres)=1.1e-06
# it=1 var=1.67e+01
#    -1.98e+00<=UPDATE<=2.54e+02, deltat=9.22e-02
# ierr=0 avg_it=0034 max(res)=9.2e-09 max(pres)=9.1e-07
# it=2 var=6.19e+00
#    -2.37e+00<=UPDATE<=6.45e+01, deltat=1.00e-01
# ierr=0 avg_it=0033 max(res)=1.0e-08 max(pres)=9.4e-07
# it=3 var=1.95e+00
#    -2.36e+00<=UPDATE<=5.39e+01, deltat=1.00e-01
# ierr=0 avg_it=0032 max(res)=1.0e-08 max(pres)=9.6e-07
# it=4 var=1.32e+00
#    -2.26e+00<=UPDATE<=4.66e+01, deltat=1.00e-01
# ierr=0 avg_it=0031 max(res)=9.4e-09 max(pres)=9.7e-07
# it=5 var=9.90e-01
#    -2.57e+00<=UPDATE<=4.10e+01, deltat=1.00e-01
# ierr=0 avg_it=0031 max(res)=9.9e-09 max(pres)=9.9e-07
# it=6 var=7.83e-01
#    -2.76e+00<=UPDATE<=3.64e+01, deltat=1.00e-01
# ierr=0 avg_it=0031 max(res)=9.4e-09 max(pres)=1.1e-06
# it=7 var=6.44e-01
#    -2.84e+00<=UPDATE<=3.26e+01, deltat=1.00e-01
# ierr=0 avg_it=0030 max(res)=9.9e-09 max(pres)=9.1e-07
# it=8 var=5.44e-01
#    -2.84e+00<=UPDATE<=2.94e+01, deltat=1.00e-01
# ierr=0 avg_it=0030 max(res)=9.8e-09 max(pres)=1.0e-06
# it=9 var=4.69e-01
#    -2.78e+00<=UPDATE<=2.66e+01, deltat=1.00e-01
# ierr=0 avg_it=0030 max(res)=9.4e-09 max(pres)=1.0e-06
# it=10 var=4.12e-01
#    -2.85e+00<=UPDATE<=2.42e+01, deltat=1.00e-01
# ierr=0 avg_it=0030 max(res)=9.5e-09 max(pres)=8.7e-07
# it=11 var=3.68e-01
#    -2.87e+00<=UPDATE<=2.21e+01, deltat=1.00e-01
# ierr=0 avg_it=0030 max(res)=9.9e-09 max(pres)=1.0e-06
# it=12 var=3.32e-01
#    -2.90e+00<=UPDATE<=2.02e+01, deltat=1.00e-01
# ierr=0 avg_it=0029 max(res)=9.6e-09 max(pres)=1.1e-06
# it=13 var=3.03e-01
#    -3.29e+00<=UPDATE<=1.86e+01, deltat=1.00e-01
# ierr=0 avg_it=0029 max(res)=9.8e-09 max(pres)=1.1e-06
# it=14 var=2.79e-01
#    -3.58e+00<=UPDATE<=1.77e+01, deltat=1.00e-01
# ierr=0 avg_it=0029 max(res)=9.7e-09 max(pres)=1.1e-06
# it=15 var=2.59e-01
#    -3.79e+00<=UPDATE<=1.72e+01, deltat=1.00e-01
# ierr=0 avg_it=0029 max(res)=9.8e-09 max(pres)=1.0e-06
# it=16 var=2.41e-01
#    -3.93e+00<=UPDATE<=1.68e+01, deltat=1.00e-01
# ierr=0 avg_it=0029 max(res)=9.7e-09 max(pres)=1.0e-06
# it=17 var=2.27e-01
#    -4.01e+00<=UPDATE<=1.64e+01, deltat=1.00e-01
# ierr=0 avg_it=0029 max(res)=9.7e-09 max(pres)=9.2e-07
# it=18 var=2.14e-01
#    -4.06e+00<=UPDATE<=1.60e+01, deltat=1.00e-01
# ierr=0 avg_it=0029 max(res)=1.0e-08 max(pres)=9.3e-07
# it=19 var=2.03e-01
#    -4.06e+00<=UPDATE<=1.57e+01, deltat=1.00e-01
# ierr=0 avg_it=0029 max(res)=9.9e-09 max(pres)=9.6e-07
# it=20 var=1.93e-01
# (<networkx.classes.graph.Graph at 0x79f0e3f04fd0>,
#  array([0.2918922 , 0.2918922 , 0.47214825, ..., 1.58621032, 1.00916925,
#         0.35388999], shape=(2241,)))
