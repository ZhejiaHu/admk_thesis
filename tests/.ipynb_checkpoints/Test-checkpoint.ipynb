# %%
import warnings
warnings.filterwarnings("ignore")
from test_multicommodity import test_main, create_forcing, plot_result
from mcopt_misc import plot_network, run_mcopt
import sys
sys.path.append('../src/')
import numpy as np
from mcopt import McOpt, paris_topology
from typing import Dict, List, Tuple
import networkx as nx
import matplotlib.pyplot as plt

# %% [markdown]
# #### Compare With McOpt

# %%
def constrcut_mcopt(beta: float=1.0, method="paris"):
    method, coupling, museed, pflux, rho = method, "l1", 0, beta, 0.0   
    time_step, tot_time, relax_linsys, tau_cond_dyn, tau_cost_dyn = 0.5, 10000, 1.0e-5, 1.0e-1, 1.0e-1
    tau_cond_opt, tau_cost_opt = 1.0e-1, 1.0e-1
    VERBOSE = False
    mcopt = McOpt(method, coupling, museed, pflux, VERBOSE, rho, relax_linsys, tau_cond_dyn, tau_cost_dyn, time_step, tot_time, tau_cond_opt, tau_cost_opt)
    mcopt.ot_setup()
    return mcopt

# %%
def compare_mcopt_admk(beta: float=1.0, method="paris"):
    mcopt = constrcut_mcopt(beta=beta, method=method)
    forcing, conductivity_mcopt = run_mcopt(mcopt)
    topo, weights, forcing_ = mcopt.export_setup()
    potentials, conductivity_admk, potentials_admk = test_main(topo.copy(), weights, len(forcing_[0]), forcing_, beta=beta, max_iter=25)
    plot_network(mcopt.g, forcing, conductivity_mcopt, conductivity_admk)
    print(conductivity_admk[0])
    return mcopt.g, forcing_

# %%
graph, forcing = compare_mcopt_admk(1, "synth")
# Out:
# * graph topology construction
# * running [dynamics]
# 	convergence achieved [dynamics]
# * export fluxes
# * export cost
# init signature: (self, tol_optimization=0.001, tol_constraint=1e-08, method='explicit_tdens', max_iter=200, max_restart=5, method_ctrl=None, verbose=0, log=0, log_file='admk.log', beta=1, log_print: bool = True)
# ierr=0 avg_it=0010 max(res)=7.4e-09 max(pres)=6.4e-07
#    1.31e+01<=UPDATE<=2.04e+03, deltat=1.96e-03
# ierr=0 avg_it=0010 max(res)=9.9e-09 max(pres)=9.6e-07
# it=1 var=1.87e+02
#    8.75e+00<=UPDATE<=9.64e+02, deltat=2.01e-02
# ierr=0 avg_it=0012 max(res)=8.7e-09 max(pres)=7.5e-07
# it=2 var=3.52e+01
#    1.75e+00<=UPDATE<=2.60e+02, deltat=1.00e-01
# ierr=0 avg_it=0012 max(res)=9.6e-09 max(pres)=6.6e-07
# it=3 var=5.36e+00
#    -1.18e+00<=UPDATE<=9.83e+01, deltat=1.00e-01
# ierr=0 avg_it=0011 max(res)=9.7e-09 max(pres)=8.1e-07
# it=4 var=1.65e+00
#    -1.63e+00<=UPDATE<=6.69e+01, deltat=1.00e-01
# ierr=0 avg_it=0011 max(res)=8.5e-09 max(pres)=7.9e-07
# it=5 var=1.02e+00
#    -1.76e+00<=UPDATE<=4.92e+01, deltat=1.00e-01
# ierr=0 avg_it=0011 max(res)=9.1e-09 max(pres)=8.5e-07
# it=6 var=7.04e-01
#    -1.84e+00<=UPDATE<=3.75e+01, deltat=1.00e-01
# ierr=0 avg_it=0011 max(res)=8.8e-09 max(pres)=7.1e-07
# it=7 var=5.16e-01
#    -2.00e+00<=UPDATE<=2.93e+01, deltat=1.00e-01
# ierr=0 avg_it=0010 max(res)=9.5e-09 max(pres)=8.1e-07
# it=8 var=3.93e-01
#    -2.05e+00<=UPDATE<=2.32e+01, deltat=1.00e-01
# ierr=0 avg_it=0010 max(res)=8.7e-09 max(pres)=6.1e-07
# it=9 var=3.07e-01
#    -2.03e+00<=UPDATE<=1.87e+01, deltat=1.00e-01
# ierr=0 avg_it=0010 max(res)=9.5e-09 max(pres)=4.9e-07
# it=10 var=2.46e-01
#    -2.07e+00<=UPDATE<=1.52e+01, deltat=1.00e-01
# ierr=0 avg_it=0010 max(res)=9.8e-09 max(pres)=5.2e-07
# it=11 var=2.00e-01
#    -2.15e+00<=UPDATE<=1.27e+01, deltat=1.00e-01
# ierr=0 avg_it=0010 max(res)=9.8e-09 max(pres)=6.7e-07
# it=12 var=1.66e-01
#    -2.19e+00<=UPDATE<=1.12e+01, deltat=1.00e-01
# ierr=0 avg_it=0010 max(res)=7.9e-09 max(pres)=4.7e-07
# it=13 var=1.40e-01
#    -2.20e+00<=UPDATE<=1.03e+01, deltat=1.00e-01
# ierr=0 avg_it=0010 max(res)=9.9e-09 max(pres)=5.7e-07
# it=14 var=1.19e-01
#    -2.18e+00<=UPDATE<=9.54e+00, deltat=1.00e-01
# ierr=0 avg_it=0010 max(res)=9.6e-09 max(pres)=8.5e-07
# it=15 var=1.03e-01
#    -2.15e+00<=UPDATE<=8.85e+00, deltat=1.00e-01
# ierr=0 avg_it=0010 max(res)=1.0e-08 max(pres)=7.9e-07
# it=16 var=9.05e-02
#    -2.12e+00<=UPDATE<=8.24e+00, deltat=1.00e-01
# ierr=0 avg_it=0010 max(res)=9.3e-09 max(pres)=8.9e-07
# it=17 var=8.03e-02
#    -2.10e+00<=UPDATE<=7.69e+00, deltat=1.00e-01
# ierr=0 avg_it=0010 max(res)=9.2e-09 max(pres)=6.5e-07
# it=18 var=7.20e-02
#    -2.06e+00<=UPDATE<=7.20e+00, deltat=1.00e-01
# ierr=0 avg_it=0010 max(res)=9.8e-09 max(pres)=7.9e-07
# it=19 var=6.52e-02
#    -2.02e+00<=UPDATE<=6.74e+00, deltat=1.00e-01
# ierr=0 avg_it=0009 max(res)=9.8e-09 max(pres)=9.2e-07
# it=20 var=5.96e-02
#    -1.98e+00<=UPDATE<=6.33e+00, deltat=1.00e-01
# ierr=0 avg_it=0010 max(res)=9.9e-09 max(pres)=9.0e-07
# it=21 var=5.49e-02
#    -1.93e+00<=UPDATE<=5.95e+00, deltat=1.00e-01
# ierr=0 avg_it=0009 max(res)=9.7e-09 max(pres)=9.1e-07
# it=22 var=5.09e-02
#    -1.88e+00<=UPDATE<=5.60e+00, deltat=1.00e-01
# ierr=0 avg_it=0009 max(res)=9.3e-09 max(pres)=8.5e-07
# it=23 var=4.74e-02
#    -1.83e+00<=UPDATE<=5.27e+00, deltat=1.00e-01
# ierr=0 avg_it=0009 max(res)=9.0e-09 max(pres)=8.2e-07
# it=24 var=4.45e-02
#    -1.78e+00<=UPDATE<=4.96e+00, deltat=1.00e-01
# ierr=0 avg_it=0009 max(res)=9.5e-09 max(pres)=8.0e-07
# it=25 var=4.19e-02
# tdens_admk_: [ 7.85302894 29.86656274 44.87686292  3.85232377 52.8222392   1.84778063
#  20.55041043  6.63041964  7.16507627 61.44429694 29.90098723 59.78649803
#  25.83434613  3.76852481 55.54791346 15.97953585 51.38401258 61.34183498
#  34.951595    0.71977223 20.78484098 41.94030353 66.23189659 64.32780453
#   2.51907016  3.57968482  4.31684125  1.172828   26.53102898  1.29003556
#  23.91353699 49.37471252 19.11745335 21.69326931  5.55819183 10.51507476
#  23.81233708 64.36389967  2.72753567 33.64565499  1.42337147 85.13048856
#   0.98788729 62.78283303  3.0239989   5.45295097  5.51451835 53.76029101
#  16.39328442 46.84472746  3.28227479  7.53179091  2.46683152 92.59274385
#  56.13839667 17.73584975 32.72861487 18.77353776  5.57482995 16.81224658
#   2.3875713   0.83595927  1.36245488 53.314162    5.91919373 15.56775592
#   2.26739574 37.5101742   0.68269309 26.53993394  3.63069466 29.01917867
#   1.41371379 11.59163344 40.55717955  4.20960549]
# 7.853028942043245

# %% [markdown]
# ###### Apply Fine-Grain Method On Waxman Graph

# %%
def discretize(graph: nx.Graph, forcing: List[np.ndarray], mesh_size=20, beta=1, max_iter=20):
    def grid_coord_idx(coord: Tuple[int, int]): 
        return coord[0] * mesh_size + coord[1]
    
    mesh = nx.grid_2d_graph(mesh_size, mesh_size)
    num_commodity = len(mesh.nodes)
    forcing_grid = [np.zeros(num_commodity) for _ in range(mesh_size * mesh_size)]
    node_to_idx = {}
    for node in graph.nodes:
        cur_pos_on_grid: Tuple[int, int] = (round(graph.nodes[node]["pos"][0] * mesh_size), round(graph.nodes[node]["pos"][1] * mesh_size))
        print(f"Original pos: {graph.nodes[node]['pos']} | Pos on grid: {cur_pos_on_grid}")
        cur_pos_idx = grid_coord_idx(cur_pos_on_grid)
        node_to_idx[node] = cur_pos_idx
    for node in graph.nodes:
        for comm in range(len(graph.nodes)):
            forcing_grid[node_to_idx[node]][node_to_idx[comm]] += forcing[node][comm]
    for node in mesh.nodes():
        mesh.nodes[node]["amplitude"] = np.linalg.norm(forcing_grid[grid_coord_idx(node)])
    edge_lists = np.array([list((grid_coord_idx(e[0]), grid_coord_idx(e[1]))) for e in mesh.edges()])
    weights = np.ones_like(edge_lists[:,0])
    potentials, conductivity_admk, potentials_admk = test_main(edge_lists, weights, num_commodity, forcing_grid, beta=beta, max_iter=max_iter)
    plt.show()
    pos = {n: (n[0], n[1]) for n in mesh.nodes()}
    nx.draw_networkx_edges(mesh, pos=pos, width=np.array(conductivity_admk) * 0.1,  edge_color='C0', style='solid')
    amps = [mesh.nodes[n]['amplitude']  for n in mesh.nodes()]
    nx.draw_networkx_nodes(mesh, pos=pos, node_size=amps, node_color='orange')
    plt.show()
    return mesh, conductivity_admk

# %% [markdown]
# The scale of the `forcing` needs to be altered for different methods and topology, here we set it to `1e5`, which <ins>might not work</ins> for alternative problems (optimization might not run properly).

# %%
discretize(graph, forcing)
# Out:
# Original pos: (0.8444218515250481, 0.7579544029403025) | Pos on grid: (17, 15)
# Original pos: (0.420571580830845, 0.25891675029296335) | Pos on grid: (8, 5)
# Original pos: (0.5112747213686085, 0.4049341374504143) | Pos on grid: (10, 8)
# Original pos: (0.7837985890347726, 0.30331272607892745) | Pos on grid: (16, 6)
# Original pos: (0.4765969541523558, 0.5833820394550312) | Pos on grid: (10, 12)
# Original pos: (0.9081128851953352, 0.5046868558173903) | Pos on grid: (18, 10)
# Original pos: (0.28183784439970383, 0.7558042041572239) | Pos on grid: (6, 15)
# Original pos: (0.6183689966753316, 0.25050634136244054) | Pos on grid: (12, 5)
# Original pos: (0.9097462559682401, 0.9827854760376531) | Pos on grid: (18, 20)
# Original pos: (0.8102172359965896, 0.9021659504395827) | Pos on grid: (16, 18)
# Original pos: (0.3101475693193326, 0.7298317482601286) | Pos on grid: (6, 15)
# Original pos: (0.8988382879679935, 0.6839839319154413) | Pos on grid: (18, 14)
# Original pos: (0.47214271545271336, 0.1007012080683658) | Pos on grid: (9, 2)
# Original pos: (0.4341718354537837, 0.6108869734438016) | Pos on grid: (9, 12)
# Original pos: (0.9130110532378982, 0.9666063677707588) | Pos on grid: (18, 19)
# Original pos: (0.47700977655271704, 0.8653099277716401) | Pos on grid: (10, 17)
# Original pos: (0.2604923103919594, 0.8050278270130223) | Pos on grid: (5, 16)
# Original pos: (0.5486993038355893, 0.014041700164018955) | Pos on grid: (11, 0)
# Original pos: (0.7197046864039541, 0.39882354222426875) | Pos on grid: (14, 8)
# Original pos: (0.824844977148233, 0.6681532012318508) | Pos on grid: (16, 13)
# Original pos: (0.0011428193144282783, 0.49357786646532464) | Pos on grid: (0, 10)
# Original pos: (0.8676027754927809, 0.24391087688713198) | Pos on grid: (17, 5)
# Original pos: (0.32520436274739006, 0.8704712321086546) | Pos on grid: (7, 17)
# Original pos: (0.19106709150239054, 0.5675107406206719) | Pos on grid: (4, 11)
# Original pos: (0.23861592861522019, 0.9675402502901433) | Pos on grid: (5, 19)
# Original pos: (0.80317946927987, 0.44796957143557037) | Pos on grid: (16, 9)
# Original pos: (0.08044581855253541, 0.32005460467254576) | Pos on grid: (2, 6)
# Original pos: (0.5079406425205739, 0.9328338242269067) | Pos on grid: (10, 19)
# Original pos: (0.10905784593110368, 0.5512672460905512) | Pos on grid: (2, 11)
# Original pos: (0.7065614098668896, 0.5474409113284238) | Pos on grid: (14, 11)
# init signature: (self, tol_optimization=0.001, tol_constraint=1e-08, method='explicit_tdens', max_iter=200, max_restart=5, method_ctrl=None, verbose=0, log=0, log_file='admk.log', beta=1, log_print: bool = True)
# ierr=0 avg_it=0001 max(res)=9.8e-09 max(pres)=8.2e-07
#    -1.43e+00<=UPDATE<=1.21e+03, deltat=3.29e-03
# ierr=0 avg_it=0001 max(res)=9.9e-09 max(pres)=8.1e-07
# it=1 var=5.56e+01
#    -1.46e+00<=UPDATE<=4.03e+02, deltat=3.74e-02
# ierr=0 avg_it=0002 max(res)=9.6e-09 max(pres)=6.6e-07
# it=2 var=1.62e+01
#    -1.60e+00<=UPDATE<=9.69e+01, deltat=1.00e-01
# ierr=0 avg_it=0001 max(res)=9.9e-09 max(pres)=8.8e-07
# it=3 var=3.59e+00
#    -1.54e+00<=UPDATE<=5.68e+01, deltat=1.00e-01
# ierr=0 avg_it=0001 max(res)=9.8e-09 max(pres)=9.3e-07
# it=4 var=1.56e+00
#    -1.45e+00<=UPDATE<=4.14e+01, deltat=1.00e-01
# ierr=0 avg_it=0001 max(res)=9.0e-09 max(pres)=7.5e-07
# it=5 var=9.88e-01
#    -1.34e+00<=UPDATE<=3.22e+01, deltat=1.00e-01
# ierr=0 avg_it=0001 max(res)=9.8e-09 max(pres)=9.7e-07
# it=6 var=6.97e-01
#    -1.28e+00<=UPDATE<=2.59e+01, deltat=1.00e-01
# ierr=0 avg_it=0001 max(res)=9.3e-09 max(pres)=8.5e-07
# it=7 var=5.22e-01
#    -1.49e+00<=UPDATE<=2.14e+01, deltat=1.00e-01
# ierr=0 avg_it=0001 max(res)=9.8e-09 max(pres)=6.6e-07
# it=8 var=4.08e-01
#    -1.76e+00<=UPDATE<=1.79e+01, deltat=1.00e-01
# ierr=0 avg_it=0001 max(res)=9.9e-09 max(pres)=9.4e-07
# it=9 var=3.30e-01
#    -2.23e+00<=UPDATE<=1.53e+01, deltat=1.00e-01
# ierr=0 avg_it=0001 max(res)=9.6e-09 max(pres)=8.1e-07
# it=10 var=2.73e-01
#    -2.55e+00<=UPDATE<=1.33e+01, deltat=1.00e-01
# ierr=0 avg_it=0001 max(res)=9.9e-09 max(pres)=1.0e-06
# it=11 var=2.32e-01
#    -2.75e+00<=UPDATE<=1.20e+01, deltat=1.00e-01
# ierr=0 avg_it=0001 max(res)=9.9e-09 max(pres)=8.8e-07
# it=12 var=2.01e-01
#    -2.87e+00<=UPDATE<=1.09e+01, deltat=1.00e-01
# ierr=0 avg_it=0001 max(res)=9.9e-09 max(pres)=1.2e-06
# it=13 var=1.78e-01
#    -3.06e+00<=UPDATE<=1.00e+01, deltat=1.00e-01
# ierr=0 avg_it=0001 max(res)=9.9e-09 max(pres)=1.1e-06
# it=14 var=1.60e-01
#    -3.18e+00<=UPDATE<=9.27e+00, deltat=1.00e-01
# ierr=0 avg_it=0001 max(res)=9.8e-09 max(pres)=1.2e-06
# it=15 var=1.46e-01
#    -3.26e+00<=UPDATE<=8.64e+00, deltat=1.00e-01
# ierr=0 avg_it=0001 max(res)=9.8e-09 max(pres)=9.8e-07
# it=16 var=1.35e-01
#    -3.29e+00<=UPDATE<=8.11e+00, deltat=1.00e-01
# ierr=0 avg_it=0001 max(res)=9.8e-09 max(pres)=9.0e-07
# it=17 var=1.26e-01
#    -3.29e+00<=UPDATE<=7.66e+00, deltat=1.00e-01
# ierr=0 avg_it=0001 max(res)=1.0e-08 max(pres)=9.3e-07
# it=18 var=1.18e-01
#    -3.28e+00<=UPDATE<=7.27e+00, deltat=1.00e-01
# ierr=0 avg_it=0001 max(res)=9.7e-09 max(pres)=1.1e-06
# it=19 var=1.12e-01
#    -3.24e+00<=UPDATE<=6.99e+00, deltat=1.00e-01
# ierr=0 avg_it=0001 max(res)=9.9e-09 max(pres)=9.5e-07
# it=20 var=1.06e-01
# (<networkx.classes.graph.Graph at 0x7a6f3c69e530>,
#  array([ 0.46707129,  0.46707129,  0.49580237,  0.82721469,  0.54127393,
#          1.27096063,  0.60713692,  1.79612185,  0.72068165,  2.43979714,
#          0.98779615,  3.33870316,  1.77618187,  4.97170757,  2.05806403,
#          6.976731  ,  3.22688542, 10.12075926,  7.93711616, 17.78749667,
#         57.13554321, 26.43629635, 18.52008529,  8.62213353,  3.53928912,
#          5.26137291,  1.60922801,  3.73288335,  1.09962114,  2.6971387 ,
#          9.48211359, 29.16347475,  5.12340192,  8.27095583,  4.65757032,
#         10.99836713,  5.25260695,  4.61647256,  4.43575159,  4.84486559,
#          3.38514872, 17.60770916,  2.44089897,  7.49663267, 32.87732596,
#          3.96790336, 11.3639652 ,  5.82280164,  5.35250842,  6.67031224,
#          3.50870365,  7.17947748,  4.31765985,  8.19914914, 32.97763879,
#         24.90799573, 18.61409847, 30.30640228,  2.75527048, 28.61052403,
#          3.63780697, 31.24462463, 16.39876739, 32.25086727, 16.10922202,
#         29.4594295 ,  4.06062038, 31.58657263,  3.34601689, 37.10302898,
#         22.04076317, 26.32566941, 12.65730557, 16.87436849, 21.69547729,
#         15.4679628 ,  4.47814394, 17.12474167,  3.85274565, 20.38445267,
#          7.53969556,  5.44265243,  3.91325892, 38.33346441,  8.23502289,
#         14.22644253, 13.0621709 ,  7.68896286, 17.17109864,  5.48051169,
#         21.1222258 ,  5.3278406 , 25.89935799, 18.05981884, 32.53531469,
#          3.08959083, 19.8825594 ,  1.76669655, 18.12219269,  2.43333532,
#         16.21579841,  8.70917267, 14.85973564, 28.67920988, 12.64789237,
#          3.44436815, 12.6236154 ,  2.54192782, 12.33522865,  9.33906932,
#         17.29700469, 26.77111666, 28.87112131,  8.99875231, 13.19107992,
#          0.88495006,  9.31685353,  0.91574961,  6.15787889,  2.45250198,
#          1.27913664,  4.16540195, 51.94748036, 15.61870845, 15.19227027,
#         17.3377048 ,  7.32594437, 17.28028437,  4.76389928, 16.72081961,
#          4.32739825, 15.97799903,  7.2881525 , 13.06976549,  2.0393547 ,
#         14.69150886,  1.15759111, 16.06947152,  1.02734856, 17.97046629,
#          1.24977173, 24.17596584,  5.00331811, 25.467715  ,  0.56664253,
#         23.74670765,  0.46275354, 23.31699655,  0.8155087 , 25.20668369,
#          3.02087905, 10.9072296 ,  0.69801368,  3.85909362,  0.40596368,
#          3.46247815,  0.41424647,  3.20408371,  0.59018901,  3.56480729,
#          0.89635244, 47.10236858, 32.38947229, 25.28627305, 20.71487349,
#         16.76040512, 11.38800612,  9.9660559 ,  9.09634126,  8.25977972,
#          7.20436649,  4.90598686,  4.81840697,  4.56625697,  3.86759691,
#          1.82989999,  1.66128344,  1.53946718,  1.31721603,  0.89635244]))

# %% [markdown]
# We set beta to a different value to observe if the generated result has a different pattern.

# %% [markdown]
# **Conclusions**:
# 1. It seems that we need to postprocess the result generating from the mesh. For instance, we need run some <inv>pruning algorithm</inv> to remove unnecessary edges (whose conductivity is so small), while maintaining the connectivity of the graph.
# 2. Though we are not allowed to provide the edge information, but if certain amount of mass is transferred from vertex $u$ to $v$, shaall we add weights of the edge that connect the paths between $u$ and $v$.

# %% [markdown]
# #### Triangular Lattice Graph

# %%
def discretize_triangular(graph: nx.Graph, forcing: List[np.ndarray], mesh_size=18, beta=1, max_iter=20):
    X_SCALE, Y_SCALE = mesh_size - 1, (mesh_size - 1) * (np.sqrt(3) / 2)
    mesh = nx.triangular_lattice_graph(mesh_size, mesh_size * 2)
    num_commodity = len(mesh.nodes()) 
    nodes_list = list(mesh.nodes())          
    key_to_index = {key: idx for idx, key in enumerate(nodes_list)}
    idx_to_key = {idx: key for key, idx in key_to_index.items()}
    
    def coordinate_to_key(coord):
        y = int(coord[1] / (np.sqrt(3) / 2) + 0.5)
        x = round(coord[0]) if y % 2 == 0 else round(coord[0] - 0.5)
        return (x, y)

    forcing_grid = [np.zeros(num_commodity) for _ in range(len(mesh.nodes()))]
    print(f"Size of the forcing grid is {len(forcing_grid)}")
    node_to_index = {}
    for node in graph.nodes:
        raw_pos = (graph.nodes[node]["pos"][0] * X_SCALE, graph.nodes[node]["pos"][1] * Y_SCALE)
        key = coordinate_to_key(raw_pos)
        index = key_to_index[key]
        node_to_index[node] = index
    for node in graph.nodes:
        for comm in range(len(graph.nodes)):
            forcing_grid[node_to_index[node]][node_to_index[comm]] += forcing[node][comm]
    for node in mesh.nodes():
        mesh.nodes[node]["amplitude"] = np.linalg.norm(forcing_grid[key_to_index[node]])
    edge_lists = np.array([list((key_to_index[e[0]], key_to_index[e[1]])) for e in mesh.edges()])
    weights = np.ones_like(edge_lists[:,0])
    potentials, conductivity_admk, potentials_admk = test_main(edge_lists, weights, num_commodity, forcing_grid, beta=beta, max_iter=max_iter)
    # for cpot in potentials: print(cpot[0:20])
    plt.show()
    pos = {n: (n[0], n[1]) for n in mesh.nodes()}
    nx.draw_networkx_edges(mesh, pos=pos, width=np.array(conductivity_admk) * 0.2,  edge_color='C0', style='solid')
    amps = [mesh.nodes[n]['amplitude']  for n in mesh.nodes()]
    nx.draw_networkx_nodes(mesh, pos=pos, node_size=amps, node_color='orange')
    plt.show()
    return mesh, conductivity_admk

# %%
discretize_triangular(graph, forcing, max_iter=10, beta=1)
# Out:
# Size of the forcing grid is 361
# init signature: (self, tol_optimization=0.001, tol_constraint=1e-08, method='explicit_tdens', max_iter=200, max_restart=5, method_ctrl=None, verbose=0, log=0, log_file='admk.log', beta=1, log_print: bool = True)
# ierr=0 avg_it=0002 max(res)=9.9e-09 max(pres)=9.6e-07
#    -2.00e+00<=UPDATE<=5.75e+02, deltat=6.96e-03
# ierr=0 avg_it=0001 max(res)=9.7e-09 max(pres)=9.2e-07
# it=1 var=2.34e+01
#    -1.99e+00<=UPDATE<=2.01e+02, deltat=7.22e-02
# ierr=0 avg_it=0001 max(res)=9.0e-09 max(pres)=7.1e-07
# it=2 var=7.84e+00
#    -1.91e+00<=UPDATE<=5.63e+01, deltat=1.00e-01
# ierr=0 avg_it=0001 max(res)=9.2e-09 max(pres)=7.7e-07
# it=3 var=2.20e+00
#    -2.18e+00<=UPDATE<=4.09e+01, deltat=1.00e-01
# ierr=0 avg_it=0001 max(res)=9.9e-09 max(pres)=9.3e-07
# it=4 var=1.31e+00
#    -2.47e+00<=UPDATE<=3.26e+01, deltat=1.00e-01
# ierr=0 avg_it=0001 max(res)=1.0e-08 max(pres)=9.4e-07
# it=5 var=9.14e-01
#    -2.52e+00<=UPDATE<=2.71e+01, deltat=1.00e-01
# ierr=0 avg_it=0001 max(res)=9.8e-09 max(pres)=8.5e-07
# it=6 var=6.89e-01
#    -2.59e+00<=UPDATE<=2.31e+01, deltat=1.00e-01
# ierr=0 avg_it=0001 max(res)=9.1e-09 max(pres)=8.6e-07
# it=7 var=5.45e-01
#    -2.87e+00<=UPDATE<=2.00e+01, deltat=1.00e-01
# ierr=0 avg_it=0001 max(res)=9.6e-09 max(pres)=8.4e-07
# it=8 var=4.46e-01
#    -3.00e+00<=UPDATE<=1.76e+01, deltat=1.00e-01
# ierr=0 avg_it=0001 max(res)=8.9e-09 max(pres)=7.2e-07
# it=9 var=3.76e-01
#    -3.04e+00<=UPDATE<=1.57e+01, deltat=1.00e-01
# ierr=0 avg_it=0001 max(res)=1.0e-08 max(pres)=9.3e-07
# it=10 var=3.23e-01
# (<networkx.classes.graph.Graph at 0x7a6f3c73f1c0>,
#  array([0.82140875, 0.82140876, 1.04123025, ..., 1.24959284, 1.38407287,
#         1.00639805], shape=(1008,)))
