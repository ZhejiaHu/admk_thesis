# %%
from test_multicommodity import test_main, create_forcing, plot_result
from mcopt_misc import plot_network, run_mcopt
import sys
sys.path.append('../src/')
import numpy as np
from mcopt import McOpt, paris_topology

# %%
topo = np.array([[0, 1], [0, 2], [0, 3], [2, 3], [1, 2], [3, 4], [0, 4]],)
weights = np.array([1, 11, 10, 4, 5, 6, 1])
potentials, conductivity = test_main(topo.copy(), weights, 2, create_forcing(5, num_commodity=2), beta=1)
plot_result(topo, weights,  2, potentials, conductivity)
# Out:
# ierr=0 avg_it=0003 max(res)=2.2e-09 max(pres)=2.5e-09
#    -1.97e+00<=UPDATE<=2.70e+00, deltat=1.00e-01
# ierr=0 avg_it=0003 max(res)=2.3e-09 max(pres)=1.0e-08
# it=1 var=1.00e+00
#    -1.78e+00<=UPDATE<=2.00e+00, deltat=1.00e-01
# ierr=0 avg_it=0003 max(res)=1.3e-09 max(pres)=6.0e-09
# it=2 var=8.96e-01
#    -1.60e+00<=UPDATE<=1.53e+00, deltat=1.00e-01
# ierr=0 avg_it=0003 max(res)=6.3e-10 max(pres)=2.8e-09
# it=3 var=8.07e-01
#    -1.45e+00<=UPDATE<=1.20e+00, deltat=1.00e-01
# ierr=0 avg_it=0003 max(res)=3.3e-10 max(pres)=1.5e-09
# it=4 var=7.29e-01
#    -1.30e+00<=UPDATE<=9.44e-01, deltat=1.00e-01
# ierr=0 avg_it=0003 max(res)=2.0e-10 max(pres)=8.8e-10
# it=5 var=6.57e-01
#    -1.17e+00<=UPDATE<=7.50e-01, deltat=1.00e-01
# ierr=0 avg_it=0003 max(res)=1.3e-10 max(pres)=5.8e-10
# it=6 var=5.91e-01
#    -1.06e+00<=UPDATE<=5.96e-01, deltat=1.00e-01
# ierr=0 avg_it=0003 max(res)=9.1e-11 max(pres)=4.1e-10
# it=7 var=5.30e-01
#    -9.50e-01<=UPDATE<=4.73e-01, deltat=1.00e-01
# ierr=0 avg_it=0003 max(res)=6.7e-11 max(pres)=3.0e-10
# it=8 var=4.73e-01
#    -8.55e-01<=UPDATE<=3.73e-01, deltat=1.00e-01
# ierr=0 avg_it=0003 max(res)=5.2e-11 max(pres)=2.3e-10
# it=9 var=4.20e-01
#    -7.69e-01<=UPDATE<=2.91e-01, deltat=1.00e-01
# ierr=0 avg_it=0003 max(res)=4.1e-11 max(pres)=1.8e-10
# it=10 var=3.72e-01
#    -6.91e-01<=UPDATE<=2.23e-01, deltat=1.00e-01
# ierr=0 avg_it=0003 max(res)=3.3e-11 max(pres)=1.5e-10
# it=11 var=3.29e-01
#    -6.21e-01<=UPDATE<=1.67e-01, deltat=1.00e-01
# ierr=0 avg_it=0003 max(res)=2.6e-11 max(pres)=1.2e-10
# it=12 var=2.90e-01
#    -5.58e-01<=UPDATE<=1.20e-01, deltat=1.00e-01
# ierr=0 avg_it=0003 max(res)=2.1e-11 max(pres)=9.6e-11
# it=13 var=2.56e-01
#    -5.02e-01<=UPDATE<=8.08e-02, deltat=1.00e-01
# ierr=0 avg_it=0003 max(res)=1.7e-11 max(pres)=7.7e-11
# it=14 var=2.26e-01
#    -4.51e-01<=UPDATE<=7.54e-02, deltat=1.00e-01
# ierr=0 avg_it=0003 max(res)=1.4e-11 max(pres)=6.2e-11
# it=15 var=2.00e-01
#    -4.05e-01<=UPDATE<=9.00e-02, deltat=1.00e-01
# ierr=0 avg_it=0003 max(res)=1.1e-11 max(pres)=4.9e-11
# it=16 var=1.79e-01
#    -3.64e-01<=UPDATE<=1.03e-01, deltat=1.00e-01
# ierr=0 avg_it=0003 max(res)=8.6e-12 max(pres)=3.8e-11
# it=17 var=1.61e-01
#    -3.27e-01<=UPDATE<=1.15e-01, deltat=1.00e-01
# ierr=0 avg_it=0003 max(res)=6.7e-12 max(pres)=2.9e-11
# it=18 var=1.47e-01
#    -2.95e-01<=UPDATE<=1.25e-01, deltat=1.00e-01
# ierr=0 avg_it=0002 max(res)=8.1e-10 max(pres)=1.8e-09
# it=19 var=1.35e-01
#    -2.65e-01<=UPDATE<=1.34e-01, deltat=1.00e-01
# ierr=0 avg_it=0002 max(res)=6.5e-10 max(pres)=1.3e-09
# it=20 var=1.25e-01
# [(np.int64(0), np.int64(1)), (np.int64(0), np.int64(2)), (np.int64(0), np.int64(3)), (np.int64(0), np.int64(4)), (np.int64(1), np.int64(2)), (np.int64(2), np.int64(3)), (np.int64(3), np.int64(4))]
# [np.int64(0), np.int64(1), np.int64(2), np.int64(3), np.int64(4)]
# {(np.int64(0), np.int64(1)): np.float64(1.71709504082293), (np.int64(0), np.int64(2)): np.float64(0.35022141353394215), (np.int64(0), np.int64(3)): np.float64(0.33304498923333065), (np.int64(0), np.int64(4)): np.float64(3.1439350613055295), (np.int64(1), np.int64(2)): np.float64(0.7167177474792569), (np.int64(2), np.int64(3)): np.float64(0.26133749862602107), (np.int64(3), np.int64(4)): np.float64(0.9205287440565557)}
# Conductivity is {(np.int64(0), np.int64(1)): np.float64(1.71709504082293), (np.int64(0), np.int64(2)): np.float64(0.35022141353394215), (np.int64(0), np.int64(3)): np.float64(0.33304498923333065), (np.int64(0), np.int64(4)): np.float64(3.1439350613055295), (np.int64(1), np.int64(2)): np.float64(0.7167177474792569), (np.int64(2), np.int64(3)): np.float64(0.26133749862602107), (np.int64(3), np.int64(4)): np.float64(0.9205287440565557)}

# %%
potentials, conductivity = test_main(topo.copy(), weights, 2, create_forcing(5, num_commodity=2), beta=2)
# Out:
# ierr=0 avg_it=0003 max(res)=2.2e-09 max(pres)=2.5e-09
#    -1.95e+00<=UPDATE<=7.39e+00, deltat=1.00e-01
# ierr=0 avg_it=0003 max(res)=4.7e-09 max(pres)=2.1e-08
# it=1 var=1.57e+00
#    -1.77e+00<=UPDATE<=7.14e+00, deltat=1.00e-01
# ierr=0 avg_it=0003 max(res)=9.4e-10 max(pres)=1.4e-09
# it=2 var=1.45e+00
#    -1.61e+00<=UPDATE<=6.71e+00, deltat=1.00e-01
# ierr=0 avg_it=0003 max(res)=9.0e-10 max(pres)=4.0e-09
# it=3 var=1.29e+00
#    -1.45e+00<=UPDATE<=6.20e+00, deltat=1.00e-01
# ierr=0 avg_it=0003 max(res)=4.3e-10 max(pres)=1.9e-09
# it=4 var=1.13e+00
#    -1.31e+00<=UPDATE<=5.69e+00, deltat=1.00e-01
# ierr=0 avg_it=0003 max(res)=2.1e-10 max(pres)=9.6e-10
# it=5 var=9.75e-01
#    -1.18e+00<=UPDATE<=5.18e+00, deltat=1.00e-01
# ierr=0 avg_it=0003 max(res)=1.1e-10 max(pres)=5.1e-10
# it=6 var=8.41e-01
#    -1.06e+00<=UPDATE<=4.69e+00, deltat=1.00e-01
# ierr=0 avg_it=0003 max(res)=6.5e-11 max(pres)=2.9e-10
# it=7 var=7.24e-01
#    -9.59e-01<=UPDATE<=4.24e+00, deltat=1.00e-01
# ierr=0 avg_it=0003 max(res)=3.9e-11 max(pres)=1.8e-10
# it=8 var=6.25e-01
#    -8.64e-01<=UPDATE<=3.81e+00, deltat=1.00e-01
# ierr=0 avg_it=0003 max(res)=2.5e-11 max(pres)=1.1e-10
# it=9 var=5.40e-01
#    -7.79e-01<=UPDATE<=3.41e+00, deltat=1.00e-01
# ierr=0 avg_it=0003 max(res)=1.6e-11 max(pres)=7.2e-11
# it=10 var=4.67e-01
#    -7.01e-01<=UPDATE<=3.05e+00, deltat=1.00e-01
# ierr=0 avg_it=0003 max(res)=1.1e-11 max(pres)=4.9e-11
# it=11 var=4.05e-01
#    -6.32e-01<=UPDATE<=2.71e+00, deltat=1.00e-01
# ierr=0 avg_it=0003 max(res)=7.6e-12 max(pres)=3.4e-11
# it=12 var=3.51e-01
#    -5.69e-01<=UPDATE<=2.40e+00, deltat=1.00e-01
# ierr=0 avg_it=0003 max(res)=5.4e-12 max(pres)=2.4e-11
# it=13 var=3.05e-01
#    -5.12e-01<=UPDATE<=2.11e+00, deltat=1.00e-01
# ierr=0 avg_it=0003 max(res)=3.9e-12 max(pres)=1.7e-11
# it=14 var=2.64e-01
#    -4.66e-01<=UPDATE<=1.85e+00, deltat=1.00e-01
# ierr=0 avg_it=0003 max(res)=2.8e-12 max(pres)=1.3e-11
# it=15 var=2.29e-01
#    -4.25e-01<=UPDATE<=1.61e+00, deltat=1.00e-01
# ierr=0 avg_it=0003 max(res)=2.1e-12 max(pres)=9.2e-12
# it=16 var=1.99e-01
#    -3.88e-01<=UPDATE<=1.39e+00, deltat=1.00e-01
# ierr=0 avg_it=0003 max(res)=1.5e-12 max(pres)=6.8e-12
# it=17 var=1.73e-01
#    -3.55e-01<=UPDATE<=1.20e+00, deltat=1.00e-01
# ierr=0 avg_it=0002 max(res)=9.0e-10 max(pres)=4.0e-09
# it=18 var=1.50e-01
#    -3.25e-01<=UPDATE<=1.02e+00, deltat=1.00e-01
# ierr=0 avg_it=0002 max(res)=6.9e-10 max(pres)=3.1e-09
# it=19 var=1.30e-01
#    -2.98e-01<=UPDATE<=8.60e-01, deltat=1.00e-01
# ierr=0 avg_it=0002 max(res)=5.1e-10 max(pres)=2.3e-09
# it=20 var=1.14e-01

# %% [markdown]
# #### Compare With McOpt

# %%
def constrcut_mcopt():
    method, coupling, museed, pflux, rho = "paris", "l1", 0, 1.0, 0.0   
    time_step, tot_time, relax_linsys, tau_cond_dyn, tau_cost_dyn = 0.5, 10000, 1.0e-5, 1.0e-1, 1.0e-1
    tau_cond_opt, tau_cost_opt = 1.0e-1, 1.0e-1
    VERBOSE = False
    mcopt = McOpt(method, coupling, museed, pflux, VERBOSE, rho, relax_linsys, tau_cond_dyn, tau_cost_dyn, time_step, tot_time, tau_cond_opt, tau_cost_opt)
    mcopt.ot_setup()
    return mcopt

# %%
mcopt = constrcut_mcopt()
forcing, conductivity_mcopt = run_mcopt(mcopt)
# Out:
# * graph topology construction
# Graph: Graph with 302 nodes and 359 edges
# Forcing: [[ 7.91235900e+06 -1.14198250e+05 -3.45922617e+04 ... -1.62705497e+04
#   -1.60048456e+04 -3.92271533e+04]
#  [-1.13218685e+05  1.97543340e+07 -8.63645206e+04 ... -4.06217505e+04
#   -3.99583822e+04 -9.79361891e+04]
#  [-3.46390820e+04 -8.72296490e+04  6.04380800e+06 ... -1.24281619e+04
#   -1.22252054e+04 -2.99634259e+04]
#  ...
#  [-1.63302210e+04 -4.11234758e+04 -1.24568812e+04 ...  2.84928800e+06
#   -5.76344102e+03 -1.41259335e+04]
#  [-1.60640808e+04 -4.04532699e+04 -1.22538664e+04 ... -5.76363417e+03
#    2.80285200e+06 -1.38957174e+04]
#  [-3.92573508e+04 -9.88595751e+04 -2.99459606e+04 ... -1.40851513e+04
#   -1.38551355e+04  6.84960100e+06]]
# * running [dynamics]
# 	convergence achieved [dynamics]
# * export fluxes
# * export cost

# %%
topo, weights, forcing_ = mcopt.export_setup()
potentials, conductivity_admk = test_main(topo.copy(), weights, len(forcing_), forcing_, beta=1)
# Out:
# ierr=0 avg_it=0006 max(res)=8.1e-09 max(pres)=9.6e-07
#    5.94e+01<=UPDATE<=3.88e+04, deltat=1.03e-04
# ierr=0 avg_it=0006 max(res)=9.9e-09 max(pres)=2.2e-06
# it=1 var=2.25e+03
#    4.42e+01<=UPDATE<=1.80e+04, deltat=1.13e-03
# ierr=0 avg_it=0006 max(res)=1.0e-08 max(pres)=3.1e-06
# it=2 var=5.64e+02
#    1.64e+01<=UPDATE<=4.78e+03, deltat=1.45e-02
# ierr=0 avg_it=0006 max(res)=1.0e-08 max(pres)=3.7e-06
# it=3 var=5.15e+01
#    2.11e+00<=UPDATE<=1.24e+03, deltat=1.00e-01
# ierr=0 avg_it=0006 max(res)=9.9e-09 max(pres)=4.6e-06
# it=4 var=5.53e+00
#    -1.86e-01<=UPDATE<=3.64e+02, deltat=1.00e-01
# ierr=0 avg_it=0006 max(res)=4.3e-09 max(pres)=6.8e-07
# it=5 var=1.45e+00
#    -3.56e-01<=UPDATE<=2.44e+02, deltat=1.00e-01
# ierr=0 avg_it=0005 max(res)=9.2e-09 max(pres)=4.8e-07
# it=6 var=8.91e-01
#    -4.14e-01<=UPDATE<=1.76e+02, deltat=1.00e-01
# ierr=0 avg_it=0005 max(res)=1.0e-08 max(pres)=8.6e-07
# it=7 var=6.06e-01
#    -4.26e-01<=UPDATE<=1.31e+02, deltat=1.00e-01
# ierr=0 avg_it=0005 max(res)=1.0e-08 max(pres)=9.9e-07
# it=8 var=4.35e-01
#    -4.15e-01<=UPDATE<=9.98e+01, deltat=1.00e-01
# ierr=0 avg_it=0005 max(res)=1.0e-08 max(pres)=4.5e-06
# it=9 var=3.22e-01
#    -7.26e-01<=UPDATE<=7.69e+01, deltat=1.00e-01
# ierr=0 avg_it=0005 max(res)=9.9e-09 max(pres)=4.3e-06
# it=10 var=2.45e-01
#    -1.32e+00<=UPDATE<=5.97e+01, deltat=1.00e-01
# ierr=0 avg_it=0005 max(res)=9.8e-09 max(pres)=3.2e-06
# it=11 var=1.88e-01
#    -1.90e+00<=UPDATE<=4.67e+01, deltat=1.00e-01
# ierr=0 avg_it=0005 max(res)=9.7e-09 max(pres)=2.5e-06
# it=12 var=1.47e-01
#    -2.51e+00<=UPDATE<=3.67e+01, deltat=1.00e-01
# ierr=0 avg_it=0005 max(res)=9.6e-09 max(pres)=1.9e-06
# it=13 var=1.16e-01
#    -2.94e+00<=UPDATE<=2.88e+01, deltat=1.00e-01
# ierr=0 avg_it=0005 max(res)=8.8e-09 max(pres)=1.5e-06
# it=14 var=9.25e-02
#    -3.24e+00<=UPDATE<=2.27e+01, deltat=1.00e-01
# ierr=0 avg_it=0005 max(res)=6.8e-09 max(pres)=1.2e-06
# it=15 var=7.44e-02
#    -3.44e+00<=UPDATE<=1.80e+01, deltat=1.00e-01
# ierr=0 avg_it=0005 max(res)=3.9e-09 max(pres)=6.3e-07
# it=16 var=6.04e-02
#    -3.57e+00<=UPDATE<=1.47e+01, deltat=1.00e-01
# ierr=0 avg_it=0004 max(res)=1.0e-08 max(pres)=1.1e-06
# it=17 var=4.96e-02
#    -3.65e+00<=UPDATE<=1.28e+01, deltat=1.00e-01
# ierr=0 avg_it=0004 max(res)=1.0e-08 max(pres)=8.0e-07
# it=18 var=4.12e-02
#    -3.89e+00<=UPDATE<=1.12e+01, deltat=1.00e-01
# ierr=0 avg_it=0004 max(res)=1.0e-08 max(pres)=8.1e-07
# it=19 var=3.47e-02
#    -4.18e+00<=UPDATE<=9.99e+00, deltat=1.00e-01
# ierr=0 avg_it=0004 max(res)=9.9e-09 max(pres)=1.0e-06
# it=20 var=2.97e-02

# %%
def plot_network(graph, forcing, tdens, width_prop):
    import matplotlib.pyplot as plt
    import networkx as nx
    import numpy as np
    import pickle as pkl
    import os

    path = os.getcwd()
    input_path = path + "/../data/input/"
    with open(input_path + "comm_list.pkl", 'rb') as comm_list_f:
        comm_list = pkl.load(comm_list_f)


    inflows = np.diag(forcing)
    inflows = inflows / np.sum(inflows)

    pos = {n[0]: n[1]["pos"] for n in graph.nodes(data=True)}

    fig, ax = plt.subplots(1, 2, figsize=(10, 5))
    node_prop = 0.001

    nx.draw_networkx_edges(graph,
                           pos=pos,
                           width=width_prop * tdens,
                           edge_color='C0',
                           style='solid',
                           ax=ax[0])
    nx.draw_networkx_nodes(graph,
                           nodelist=comm_list,
                           pos=pos,
                           node_shape='o',
                           node_color='gray',
                           node_size=inflows * node_prop,
                           linewidths=0.1,
                           ax=ax[0])

    ax[0].set_title("Dynamics", size=14)
    ax[1].set_title("Optimization (Fixed-point)", size=14)

    plt.show()

# %%
plot_network(mcopt.g, forcing, conductivity_mcopt, width_prop=0.00000001)

# %%
plot_network(mcopt.g, forcing, conductivity_admk, width_prop=0.01)
