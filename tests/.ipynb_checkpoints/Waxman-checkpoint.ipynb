# %%
import warnings
warnings.filterwarnings("ignore")
from test_multicommodity import test_main, create_forcing, plot_result
from mcopt_misc import plot_network, run_mcopt
import sys
sys.path.append('../src/')
import numpy as np
from mcopt import McOpt, paris_topology
from typing import Dict, List, Tuple
import networkx as nx
import matplotlib.pyplot as plt

# %%
def constrcut_mcopt(beta: float=1.0, n=30, alpha=1, betaw=0.25, L=1.0):
    waxman_config = {"n": n, "alpha": alpha, "beta": betaw, "L": L}
    method, coupling, museed, pflux, rho = "synth", "l1", 0, beta, 0.0   
    time_step, tot_time, relax_linsys, tau_cond_dyn, tau_cost_dyn = 0.5, 10000, 1.0e-5, 1.0e-1, 1.0e-1
    tau_cond_opt, tau_cost_opt = 1.0e-1, 1.0e-1
    VERBOSE = False
    mcopt = McOpt("synth", coupling, museed, pflux, VERBOSE, rho, relax_linsys, tau_cond_dyn, tau_cost_dyn, time_step, tot_time, tau_cond_opt, tau_cost_opt, waxman_config)
    mcopt.ot_setup()
    return mcopt

# %%
def compare_mcopt_admk(beta: float=1.0, n=30, alpha=1, betaw=0.25, L=1.0):
    mcopt = constrcut_mcopt(beta, n, alpha, betaw, L)
    forcing, conductivity_mcopt = run_mcopt(mcopt)
    topo, weights, forcing_ = mcopt.export_setup()
    potentials, conductivity_admk, potentials_admk = test_main(topo.copy(), weights, len(forcing_[0]), forcing_, beta=beta, max_iter=25)
    plot_network(mcopt.g, forcing, conductivity_mcopt, conductivity_admk)
    return mcopt.g, forcing_, conductivity_mcopt

# %% [markdown]
# We only include the <ins>triangular lattice</ins> as the rectangular lattice topolgy is too restricted.

# %%
def discretize_triangular(graph: nx.Graph, forcing: List[np.ndarray], mesh_size=17, beta=1, max_iter=30, n=30, alpha=1, betaw=0.25, L=1.0):
    X_SCALE, Y_SCALE = mesh_size - 1, (mesh_size - 1) * (np.sqrt(3) / 2)
    mesh = nx.triangular_lattice_graph(mesh_size, mesh_size * 2)
    num_commodity = len(mesh.nodes()) 
    nodes_list = list(mesh.nodes())          
    key_to_index = {key: idx for idx, key in enumerate(nodes_list)}
    idx_to_key = {idx: key for key, idx in key_to_index.items()}
    
    def coordinate_to_key(coord):
        y = int(coord[1] / (np.sqrt(3) / 2) + 0.5)
        x = round(coord[0]) if y % 2 == 0 else round(coord[0] - 0.5)
        return (x, y)

    forcing_grid = [np.zeros(num_commodity) for _ in range(len(mesh.nodes()))]
    node_to_index = {}
    for node in graph.nodes:
        raw_pos = (graph.nodes[node]["pos"][0] * X_SCALE, graph.nodes[node]["pos"][1] * Y_SCALE)
        graph.nodes[node]["pos"] = raw_pos
        key = coordinate_to_key(raw_pos)
        index = key_to_index[key]
        node_to_index[node] = index
    for node in graph.nodes:
        for comm in range(len(graph.nodes)):
            forcing_grid[node_to_index[node]][node_to_index[comm]] += forcing[node][comm]
    for node in mesh.nodes():
        mesh.nodes[node]["amplitude"] = np.linalg.norm(forcing_grid[key_to_index[node]])
    edge_lists = np.array([list((key_to_index[e[0]], key_to_index[e[1]])) for e in mesh.edges()])
    weights = np.ones_like(edge_lists[:,0])
    potentials, conductivity_admk, energy = test_main(edge_lists, weights, num_commodity, forcing_grid, beta=beta, max_iter=max_iter)
    plt.show()
    pos = {n: (n[0], n[1]) for n in mesh.nodes()}
    nx.draw_networkx_edges(mesh, pos=pos, width=np.array(conductivity_admk) * 0.2,  edge_color='C0', style='solid')
    amps = [mesh.nodes[n]['amplitude']  for n in mesh.nodes()]
    nx.draw_networkx_nodes(mesh, pos=pos, node_size=amps, node_color='orange')
    plt.title(f"Triangular Lattice Approximation with Waxman Parameter: n = {n}, alpha = {alpha}, beta = {betaw}, L = {L} | Energy = {energy}")
    plt.show()
    return mesh, conductivity_admk, energy

# %%
def experiment_waxman_triangular_lattice(beta=1, n=30, alpha=1, betaw=0.25, L=1.0, mesh_size=17):
    graph, forcing, conductivity_mcopt = compare_mcopt_admk(beta=beta, n=n, alpha=alpha, betaw=betaw, L=L)
    mesh, conductivity_admk, energy_admk = discretize_triangular(graph, forcing, mesh_size=mesh_size, beta=beta, n=n, alpha=alpha, betaw=betaw, L=L)
    return graph, mesh, conductivity_mcopt, conductivity_admk, energy_admk

# %%
graph_mcopt, graph_admk, conductivity_mcopt, conductivity_admk, energy_admk = experiment_waxman_triangular_lattice(mesh_size=17)
# Out:
# * graph topology construction
# * running [dynamics]
# 	convergence achieved [dynamics]
# * export fluxes
# * export cost
# MinNorm Setup: n_row: 30, n_col: 76, self.n_rhs: 30
# init signature: (self, tol_optimization=0.001, tol_constraint=1e-08, method='explicit_tdens', max_iter=200, max_restart=5, method_ctrl=None, verbose=0, log=0, log_file='admk.log', beta=1, log_print: bool = True)
# ierr=0 avg_it=0010 max(res)=7.4e-09 max(pres)=6.4e-07
#    1.31e+01<=UPDATE<=2.04e+03, deltat=1.96e-03
# ierr=0 avg_it=0010 max(res)=9.9e-09 max(pres)=9.6e-07
# it=1 var=1.87e+02
#    8.75e+00<=UPDATE<=9.64e+02, deltat=2.01e-02
# ierr=0 avg_it=0012 max(res)=8.7e-09 max(pres)=7.5e-07
# it=2 var=3.52e+01
#    1.75e+00<=UPDATE<=2.60e+02, deltat=1.00e-01
# ierr=0 avg_it=0012 max(res)=9.6e-09 max(pres)=6.6e-07
# it=3 var=5.36e+00
#    -1.18e+00<=UPDATE<=9.83e+01, deltat=1.00e-01
# ierr=0 avg_it=0011 max(res)=9.7e-09 max(pres)=8.1e-07
# it=4 var=1.65e+00
#    -1.63e+00<=UPDATE<=6.69e+01, deltat=1.00e-01
# ierr=0 avg_it=0011 max(res)=8.5e-09 max(pres)=7.9e-07
# it=5 var=1.02e+00
#    -1.76e+00<=UPDATE<=4.92e+01, deltat=1.00e-01
# ierr=0 avg_it=0011 max(res)=9.1e-09 max(pres)=8.5e-07
# it=6 var=7.04e-01
#    -1.84e+00<=UPDATE<=3.75e+01, deltat=1.00e-01
# ierr=0 avg_it=0011 max(res)=8.8e-09 max(pres)=7.1e-07
# it=7 var=5.16e-01
#    -2.00e+00<=UPDATE<=2.93e+01, deltat=1.00e-01
# ierr=0 avg_it=0010 max(res)=9.5e-09 max(pres)=8.1e-07
# it=8 var=3.93e-01
#    -2.05e+00<=UPDATE<=2.32e+01, deltat=1.00e-01
# ierr=0 avg_it=0010 max(res)=8.7e-09 max(pres)=6.1e-07
# it=9 var=3.07e-01
#    -2.03e+00<=UPDATE<=1.87e+01, deltat=1.00e-01
# ierr=0 avg_it=0010 max(res)=9.5e-09 max(pres)=4.9e-07
# it=10 var=2.46e-01
#    -2.07e+00<=UPDATE<=1.52e+01, deltat=1.00e-01
# ierr=0 avg_it=0010 max(res)=9.8e-09 max(pres)=5.2e-07
# it=11 var=2.00e-01
#    -2.15e+00<=UPDATE<=1.27e+01, deltat=1.00e-01
# ierr=0 avg_it=0010 max(res)=9.8e-09 max(pres)=6.7e-07
# it=12 var=1.66e-01
#    -2.19e+00<=UPDATE<=1.12e+01, deltat=1.00e-01
# ierr=0 avg_it=0010 max(res)=7.9e-09 max(pres)=4.7e-07
# it=13 var=1.40e-01
#    -2.20e+00<=UPDATE<=1.03e+01, deltat=1.00e-01
# ierr=0 avg_it=0010 max(res)=9.9e-09 max(pres)=5.7e-07
# it=14 var=1.19e-01
#    -2.18e+00<=UPDATE<=9.54e+00, deltat=1.00e-01
# ierr=0 avg_it=0010 max(res)=9.6e-09 max(pres)=8.5e-07
# it=15 var=1.03e-01
#    -2.15e+00<=UPDATE<=8.85e+00, deltat=1.00e-01
# ierr=0 avg_it=0010 max(res)=1.0e-08 max(pres)=7.9e-07
# it=16 var=9.05e-02
#    -2.12e+00<=UPDATE<=8.24e+00, deltat=1.00e-01
# ierr=0 avg_it=0010 max(res)=9.3e-09 max(pres)=8.9e-07
# it=17 var=8.03e-02
#    -2.10e+00<=UPDATE<=7.69e+00, deltat=1.00e-01
# ierr=0 avg_it=0010 max(res)=9.2e-09 max(pres)=6.5e-07
# it=18 var=7.20e-02
#    -2.06e+00<=UPDATE<=7.20e+00, deltat=1.00e-01
# ierr=0 avg_it=0010 max(res)=9.8e-09 max(pres)=7.9e-07
# it=19 var=6.52e-02
#    -2.02e+00<=UPDATE<=6.74e+00, deltat=1.00e-01
# ierr=0 avg_it=0009 max(res)=9.8e-09 max(pres)=9.2e-07
# it=20 var=5.96e-02
#    -1.98e+00<=UPDATE<=6.33e+00, deltat=1.00e-01
# ierr=0 avg_it=0010 max(res)=9.9e-09 max(pres)=9.0e-07
# it=21 var=5.49e-02
#    -1.93e+00<=UPDATE<=5.95e+00, deltat=1.00e-01
# ierr=0 avg_it=0009 max(res)=9.7e-09 max(pres)=9.1e-07
# it=22 var=5.09e-02
#    -1.88e+00<=UPDATE<=5.60e+00, deltat=1.00e-01
# ierr=0 avg_it=0009 max(res)=9.3e-09 max(pres)=8.5e-07
# it=23 var=4.74e-02
#    -1.83e+00<=UPDATE<=5.27e+00, deltat=1.00e-01
# ierr=0 avg_it=0009 max(res)=9.0e-09 max(pres)=8.2e-07
# it=24 var=4.45e-02
#    -1.78e+00<=UPDATE<=4.96e+00, deltat=1.00e-01
# ierr=0 avg_it=0009 max(res)=9.5e-09 max(pres)=8.0e-07
# it=25 var=4.19e-02
# tdens_admk_: [ 7.85302894 29.86656274 44.87686292  3.85232377 52.8222392   1.84778063
#  20.55041043  6.63041964  7.16507627 61.44429694 29.90098723 59.78649803
#  25.83434613  3.76852481 55.54791346 15.97953585 51.38401258 61.34183498
#  34.951595    0.71977223 20.78484098 41.94030353 66.23189659 64.32780453
#   2.51907016  3.57968482  4.31684125  1.172828   26.53102898  1.29003556
#  23.91353699 49.37471252 19.11745335 21.69326931  5.55819183 10.51507476
#  23.81233708 64.36389967  2.72753567 33.64565499  1.42337147 85.13048856
#   0.98788729 62.78283303  3.0239989   5.45295097  5.51451835 53.76029101
#  16.39328442 46.84472746  3.28227479  7.53179091  2.46683152 92.59274385
#  56.13839667 17.73584975 32.72861487 18.77353776  5.57482995 16.81224658
#   2.3875713   0.83595927  1.36245488 53.314162    5.91919373 15.56775592
#   2.26739574 37.5101742   0.68269309 26.53993394  3.63069466 29.01917867
#   1.41371379 11.59163344 40.55717955  4.20960549]
# MinNorm Setup: n_row: 324, n_col: 901, self.n_rhs: 324
# init signature: (self, tol_optimization=0.001, tol_constraint=1e-08, method='explicit_tdens', max_iter=200, max_restart=5, method_ctrl=None, verbose=0, log=0, log_file='admk.log', beta=1, log_print: bool = True)
# ierr=0 avg_it=0002 max(res)=9.4e-09 max(pres)=7.9e-07
#    -2.00e+00<=UPDATE<=5.72e+02, deltat=6.99e-03
# ierr=0 avg_it=0002 max(res)=9.9e-09 max(pres)=9.0e-07
# it=1 var=2.59e+01
#    -1.99e+00<=UPDATE<=1.98e+02, deltat=7.05e-02
# ierr=0 avg_it=0002 max(res)=9.4e-09 max(pres)=7.9e-07
# it=2 var=8.25e+00
#    -1.94e+00<=UPDATE<=5.85e+01, deltat=1.00e-01
# ierr=0 avg_it=0002 max(res)=1.0e-08 max(pres)=9.1e-07
# it=3 var=2.24e+00
#    -2.13e+00<=UPDATE<=4.11e+01, deltat=1.00e-01
# ierr=0 avg_it=0002 max(res)=9.9e-09 max(pres)=9.5e-07
# it=4 var=1.31e+00
#    -2.37e+00<=UPDATE<=3.20e+01, deltat=1.00e-01
# ierr=0 avg_it=0002 max(res)=9.6e-09 max(pres)=1.2e-06
# it=5 var=9.11e-01
#    -2.40e+00<=UPDATE<=2.60e+01, deltat=1.00e-01
# ierr=0 avg_it=0002 max(res)=1.0e-08 max(pres)=7.6e-07
# it=6 var=6.83e-01
#    -2.38e+00<=UPDATE<=2.17e+01, deltat=1.00e-01
# ierr=0 avg_it=0002 max(res)=9.9e-09 max(pres)=9.0e-07
# it=7 var=5.37e-01
#    -2.56e+00<=UPDATE<=1.92e+01, deltat=1.00e-01
# ierr=0 avg_it=0002 max(res)=9.8e-09 max(pres)=1.2e-06
# it=8 var=4.38e-01
#    -2.63e+00<=UPDATE<=1.73e+01, deltat=1.00e-01
# ierr=0 avg_it=0002 max(res)=9.2e-09 max(pres)=8.0e-07
# it=9 var=3.67e-01
#    -2.88e+00<=UPDATE<=1.58e+01, deltat=1.00e-01
# ierr=0 avg_it=0002 max(res)=9.5e-09 max(pres)=9.1e-07
# it=10 var=3.14e-01
#    -3.22e+00<=UPDATE<=1.45e+01, deltat=1.00e-01
# ierr=0 avg_it=0002 max(res)=9.8e-09 max(pres)=8.8e-07
# it=11 var=2.74e-01
#    -3.43e+00<=UPDATE<=1.34e+01, deltat=1.00e-01
# ierr=0 avg_it=0002 max(res)=9.5e-09 max(pres)=9.4e-07
# it=12 var=2.43e-01
#    -3.57e+00<=UPDATE<=1.25e+01, deltat=1.00e-01
# ierr=0 avg_it=0002 max(res)=9.8e-09 max(pres)=8.5e-07
# it=13 var=2.19e-01
#    -3.64e+00<=UPDATE<=1.17e+01, deltat=1.00e-01
# ierr=0 avg_it=0002 max(res)=9.5e-09 max(pres)=8.9e-07
# it=14 var=1.99e-01
#    -3.67e+00<=UPDATE<=1.10e+01, deltat=1.00e-01
# ierr=0 avg_it=0002 max(res)=1.0e-08 max(pres)=9.8e-07
# it=15 var=1.82e-01
#    -3.66e+00<=UPDATE<=1.04e+01, deltat=1.00e-01
# ierr=0 avg_it=0002 max(res)=9.7e-09 max(pres)=9.4e-07
# it=16 var=1.69e-01
#    -3.63e+00<=UPDATE<=9.91e+00, deltat=1.00e-01
# ierr=0 avg_it=0001 max(res)=9.9e-09 max(pres)=9.5e-07
# it=17 var=1.57e-01
#    -3.57e+00<=UPDATE<=9.45e+00, deltat=1.00e-01
# ierr=0 avg_it=0001 max(res)=9.2e-09 max(pres)=8.3e-07
# it=18 var=1.47e-01
#    -3.51e+00<=UPDATE<=9.05e+00, deltat=1.00e-01
# ierr=0 avg_it=0001 max(res)=1.0e-08 max(pres)=7.2e-07
# it=19 var=1.39e-01
#    -3.43e+00<=UPDATE<=8.67e+00, deltat=1.00e-01
# ierr=0 avg_it=0001 max(res)=9.9e-09 max(pres)=7.6e-07
# it=20 var=1.31e-01
#    -3.34e+00<=UPDATE<=8.33e+00, deltat=1.00e-01
# ierr=0 avg_it=0001 max(res)=9.5e-09 max(pres)=8.7e-07
# it=21 var=1.24e-01
#    -3.25e+00<=UPDATE<=8.02e+00, deltat=1.00e-01
# ierr=0 avg_it=0001 max(res)=1.0e-08 max(pres)=8.8e-07
# it=22 var=1.18e-01
#    -3.16e+00<=UPDATE<=7.73e+00, deltat=1.00e-01
# ierr=0 avg_it=0001 max(res)=9.5e-09 max(pres)=8.5e-07
# it=23 var=1.13e-01
#    -3.07e+00<=UPDATE<=7.46e+00, deltat=1.00e-01
# ierr=0 avg_it=0001 max(res)=9.4e-09 max(pres)=1.1e-06
# it=24 var=1.08e-01
#    -2.97e+00<=UPDATE<=7.21e+00, deltat=1.00e-01
# ierr=0 avg_it=0001 max(res)=1.0e-08 max(pres)=1.0e-06
# it=25 var=1.03e-01
#    -2.88e+00<=UPDATE<=6.97e+00, deltat=1.00e-01
# ierr=0 avg_it=0001 max(res)=9.9e-09 max(pres)=9.2e-07
# it=26 var=9.92e-02
#    -2.78e+00<=UPDATE<=6.74e+00, deltat=1.00e-01
# ierr=0 avg_it=0001 max(res)=9.7e-09 max(pres)=8.8e-07
# it=27 var=9.54e-02
#    -2.69e+00<=UPDATE<=6.53e+00, deltat=1.00e-01
# ierr=0 avg_it=0001 max(res)=9.7e-09 max(pres)=8.0e-07
# it=28 var=9.19e-02
#    -2.60e+00<=UPDATE<=6.33e+00, deltat=1.00e-01
# ierr=0 avg_it=0001 max(res)=9.0e-09 max(pres)=7.5e-07
# it=29 var=8.86e-02
#    -2.51e+00<=UPDATE<=6.14e+00, deltat=1.00e-01
# ierr=0 avg_it=0001 max(res)=9.5e-09 max(pres)=9.5e-07
# it=30 var=8.55e-02

# %% [markdown]
# #### Wasserstein Distance between Running with or without Backbone Network

# %% [markdown]
# Because the Wasserstein Distance between two graph requires the creation of a union between two graphs.

# %%
Num_node_mcopt, Num_edge_mcopt, Num_node_admk, Num_edge_admk = len(graph_mcopt.nodes()), len(graph_mcopt.edges()), len(graph_admk.nodes()), len(graph_admk.edges())
key_to_index = {key: idx for idx, key in enumerate(graph_admk.nodes())}
def coordinate_to_key(coord):
    y = int(coord[1] / (np.sqrt(3) / 2) + 0.5)
    x = round(coord[0]) if y % 2 == 0 else round(coord[0] - 0.5)
    return (x, y)
norm_conductivity_mcopt, norm_conductivity_admk = conductivity_mcopt / np.linalg.norm(conductivity_mcopt), conductivity_admk / np.linalg.norm(conductivity_admk)
index = 0
for n, attrs in graph_mcopt.nodes(data=True): attrs["type"] = "mcopt"
for u, v, attrs in graph_mcopt.edges(data=True): 
    attrs["type"] = "mcopt"
    attrs["conductivity"] = norm_conductivity_mcopt[index]
    index += 1

index = 0
for n, attrs in graph_admk.nodes(data=True): attrs["type"] = "admk"
for u, v, attrs in graph_admk.edges(data=True): 
    attrs["type"] = "admk"
    attrs["conductivity"] = norm_conductivity_admk[index]
    index += 1

graph_union = nx.disjoint_union(graph_mcopt, graph_admk)
for node_mcopt in graph_union.nodes():
    graph_union.nodes[node_mcopt]["force"] = 0
    if node_mcopt < Num_node_mcopt:
        closest_node_admk = key_to_index[coordinate_to_key(graph_union.nodes[node_mcopt]["pos"])] + Num_node_mcopt
        graph_union.nodes[node_mcopt]["close"], graph_union.nodes[closest_node_admk]["close"] = closest_node_admk, node_mcopt
        graph_union.nodes[node_mcopt]["force"], graph_union.nodes[closest_node_admk]["force"] = 1, -1
        graph_union.add_edge(node_mcopt, closest_node_admk, type="mixed", conductivity=1)

pos = nx.get_node_attributes(graph_union, 'pos')
colors_node = list(map(lambda kv: "red" if kv[1] == "mcopt" else "blue", nx.get_node_attributes(graph_union, "type").items()))
colors_edge = list(map(lambda kv: "green" if kv[1] == "mcopt" else ("orange" if kv[1] == "mixed" else "black"), nx.get_edge_attributes(graph_union, "type").items()))
edge_mcopt_yes, edge_admk_yes, edge_mixed_yes = list(map(lambda kv: kv[1] == "mcopt", nx.get_edge_attributes(graph_union, "type").items())), list(map(lambda kv: kv[1] == "admk", nx.get_edge_attributes(graph_union, "type").items())), list(map(lambda kv: kv[1] == "mixed", nx.get_edge_attributes(graph_union, "type").items()))

# %%
nx.draw_networkx_nodes(graph_union, pos, node_color=colors_node, node_size=10)
nx.draw_networkx_edges(graph_union, pos, edge_color=colors_edge, width=np.array(list(nx.get_edge_attributes(graph_union, "conductivity").values())) * 5 * edge_mixed_yes)
plt.show()

# %%
nx.draw_networkx_nodes(graph_union, pos, node_color=colors_node, node_size=10)
nx.draw_networkx_edges(graph_union, pos, edge_color=colors_edge, width=np.array(list(nx.get_edge_attributes(graph_union, "conductivity").values())) * 30 * edge_admk_yes)
plt.show()

# %%
nx.draw_networkx_nodes(graph_union, pos, node_color=colors_node, node_size=10)
nx.draw_networkx_edges(graph_union, pos, edge_color=colors_edge, width=np.array(list(nx.get_edge_attributes(graph_union, "conductivity").values())) * 10 * edge_mcopt_yes)
plt.show()

# %%
num_commidity = len(graph_mcopt.nodes())
forcing = [np.zeros(len(graph_union.nodes())) for _ in range(num_commidity)]
print(len(forcing))
for node, attrs in graph_union.nodes(data=True):
    if attrs["force"] == 1: 
        forcing[node][node] += 1 
        forcing[node][attrs["close"]] -= 1
edge_lists = np.array([list((e[0], e[1])) for e in graph_union.edges()])
weights = np.minimum(np.array(list(nx.get_edge_attributes(graph_union, "conductivity").values())) + 1e-5, 1)
potentials, conductivity_similarity, energy_optimal = test_main(edge_lists, weights, num_commidity, forcing, max_iter=20)
pos = nx.get_node_attributes(graph_union, "pos")
plt.show()
nx.draw_networkx_edges(graph_union, pos=pos, width=np.array(conductivity_similarity) * 0.2,  edge_color='C0', style='solid')
nx.draw_networkx_nodes(graph_union, pos=pos, node_size=1, node_color='orange')
plt.title(f"Similarity | Energy = {energy_optimal}")
plt.show()
# Out:
# 30
# MinNorm Setup: n_row: 354, n_col: 1007, self.n_rhs: 30
# init signature: (self, tol_optimization=0.001, tol_constraint=1e-08, method='explicit_tdens', max_iter=200, max_restart=5, method_ctrl=None, verbose=0, log=0, log_file='admk.log', beta=1, log_print: bool = True)
# ierr=0 avg_it=0071 max(res)=9.1e-09 max(pres)=1.3e-08
#    -2.00e+00<=UPDATE<=-8.45e-01, deltat=1.00e-01
# ierr=0 avg_it=0069 max(res)=9.8e-09 max(pres)=1.4e-08
# it=1 var=1.09e+00
#    -1.80e+00<=UPDATE<=-7.02e-01, deltat=1.00e-01
# ierr=0 avg_it=0069 max(res)=1.0e-08 max(pres)=1.4e-08
# it=2 var=1.09e+00
#    -1.62e+00<=UPDATE<=-5.77e-01, deltat=1.00e-01
# ierr=0 avg_it=0069 max(res)=9.8e-09 max(pres)=1.4e-08
# it=3 var=1.09e+00
#    -1.46e+00<=UPDATE<=-4.68e-01, deltat=1.00e-01
# ierr=0 avg_it=0069 max(res)=1.0e-08 max(pres)=1.4e-08
# it=4 var=1.08e+00
#    -1.31e+00<=UPDATE<=-3.75e-01, deltat=1.00e-01
# ierr=0 avg_it=0069 max(res)=9.9e-09 max(pres)=1.4e-08
# it=5 var=1.07e+00
#    -1.18e+00<=UPDATE<=-2.96e-01, deltat=1.00e-01
# ierr=0 avg_it=0069 max(res)=1.0e-08 max(pres)=1.4e-08
# it=6 var=1.07e+00
#    -1.06e+00<=UPDATE<=-2.29e-01, deltat=1.00e-01
# ierr=0 avg_it=0069 max(res)=9.4e-09 max(pres)=1.3e-08
# it=7 var=1.06e+00
#    -9.57e-01<=UPDATE<=-1.72e-01, deltat=1.00e-01
# ierr=0 avg_it=0069 max(res)=9.2e-09 max(pres)=1.3e-08
# it=8 var=1.04e+00
#    -8.61e-01<=UPDATE<=-1.25e-01, deltat=1.00e-01
# ierr=0 avg_it=0069 max(res)=9.8e-09 max(pres)=1.4e-08
# it=9 var=1.03e+00
#    -7.75e-01<=UPDATE<=-8.49e-02, deltat=1.00e-01
# ierr=0 avg_it=0070 max(res)=9.3e-09 max(pres)=1.3e-08
# it=10 var=1.01e+00
#    -6.97e-01<=UPDATE<=-4.95e-02, deltat=1.00e-01
# ierr=0 avg_it=0070 max(res)=9.8e-09 max(pres)=1.4e-08
# it=11 var=9.94e-01
#    -6.28e-01<=UPDATE<=1.15e-03, deltat=1.00e-01
# ierr=0 avg_it=0070 max(res)=1.0e-08 max(pres)=1.4e-08
# it=12 var=9.71e-01
#    -5.65e-01<=UPDATE<=4.64e-02, deltat=1.00e-01
# ierr=0 avg_it=0070 max(res)=9.7e-09 max(pres)=1.4e-08
# it=13 var=9.44e-01
#    -5.08e-01<=UPDATE<=8.97e-02, deltat=1.00e-01
# ierr=0 avg_it=0070 max(res)=9.8e-09 max(pres)=1.4e-08
# it=14 var=9.13e-01
#    -4.58e-01<=UPDATE<=1.28e-01, deltat=1.00e-01
# ierr=0 avg_it=0070 max(res)=9.9e-09 max(pres)=1.4e-08
# it=15 var=8.78e-01
#    -4.12e-01<=UPDATE<=1.60e-01, deltat=1.00e-01
# ierr=0 avg_it=0070 max(res)=9.8e-09 max(pres)=1.4e-08
# it=16 var=8.39e-01
#    -3.71e-01<=UPDATE<=1.86e-01, deltat=1.00e-01
# ierr=0 avg_it=0071 max(res)=8.9e-09 max(pres)=1.3e-08
# it=17 var=7.95e-01
#    -3.35e-01<=UPDATE<=2.06e-01, deltat=1.00e-01
# ierr=0 avg_it=0071 max(res)=9.7e-09 max(pres)=1.4e-08
# it=18 var=7.48e-01
#    -3.04e-01<=UPDATE<=2.22e-01, deltat=1.00e-01
# ierr=0 avg_it=0071 max(res)=1.0e-08 max(pres)=1.4e-08
# it=19 var=6.98e-01
#    -2.76e-01<=UPDATE<=2.34e-01, deltat=1.00e-01
# ierr=0 avg_it=0071 max(res)=9.4e-09 max(pres)=1.3e-08
# it=20 var=6.47e-01

# %%
weights[Num_edge_mcopt:Num_edge_mcopt+Num_edge_admk] = np.minimum(np.random.rand(Num_edge_admk) + 1e-5, 1)
weights[Num_edge_mcopt:Num_edge_mcopt+Num_edge_admk] = weights[Num_edge_mcopt:Num_edge_mcopt+Num_edge_admk] / np.linalg.norm(weights[Num_edge_mcopt:Num_edge_mcopt+Num_edge_admk])
potentials, conductivity_similarity, energy_random = test_main(edge_lists, weights, num_commidity, forcing, max_iter=30)
print(f"Optimal Energy is {energy_optimal} | Current Energy is {energy_random}")
pos = nx.get_node_attributes(graph_union, "pos")
plt.show()
nx.draw_networkx_edges(graph_union, pos=pos, width=np.array(conductivity_similarity) * 0.2,  edge_color='C0', style='solid')
nx.draw_networkx_nodes(graph_union, pos=pos, node_size=1, node_color='orange')
plt.title(f"Similarity | Energy = {energy_random}")
plt.show()


weights[Num_edge_mcopt:Num_edge_mcopt+Num_edge_admk] = 0.2
weights[Num_edge_mcopt:Num_edge_mcopt+Num_edge_admk] = weights[Num_edge_mcopt:Num_edge_mcopt+Num_edge_admk] / np.linalg.norm(weights[Num_edge_mcopt:Num_edge_mcopt+Num_edge_admk])
potentials, conductivity_similarity, energy_same = test_main(edge_lists, weights, num_commidity, forcing, max_iter=30)
print(f"Optimal Energy is {energy_optimal} | Current Energy is {energy_random}")
pos = nx.get_node_attributes(graph_union, "pos")
plt.show()
nx.draw_networkx_edges(graph_union, pos=pos, width=np.array(conductivity_similarity) * 0.2,  edge_color='C0', style='solid')
nx.draw_networkx_nodes(graph_union, pos=pos, node_size=1, node_color='orange')
plt.title(f"Similarity | Energy = {energy_same}")
plt.show()
# Out:
# MinNorm Setup: n_row: 354, n_col: 1007, self.n_rhs: 30
# init signature: (self, tol_optimization=0.001, tol_constraint=1e-08, method='explicit_tdens', max_iter=200, max_restart=5, method_ctrl=None, verbose=0, log=0, log_file='admk.log', beta=1, log_print: bool = True)
# ierr=0 avg_it=0076 max(res)=1.0e-08 max(pres)=1.4e-08
#    -2.00e+00<=UPDATE<=-5.71e-01, deltat=1.00e-01
# ierr=0 avg_it=0073 max(res)=9.9e-09 max(pres)=1.4e-08
# it=1 var=1.10e+00
#    -1.80e+00<=UPDATE<=-4.48e-01, deltat=1.00e-01
# ierr=0 avg_it=0073 max(res)=9.3e-09 max(pres)=1.3e-08
# it=2 var=1.10e+00
#    -1.62e+00<=UPDATE<=-3.42e-01, deltat=1.00e-01
# ierr=0 avg_it=0073 max(res)=9.7e-09 max(pres)=1.4e-08
# it=3 var=1.09e+00
#    -1.46e+00<=UPDATE<=-2.52e-01, deltat=1.00e-01
# ierr=0 avg_it=0073 max(res)=9.8e-09 max(pres)=1.4e-08
# it=4 var=1.09e+00
#    -1.31e+00<=UPDATE<=-1.75e-01, deltat=1.00e-01
# ierr=0 avg_it=0073 max(res)=9.8e-09 max(pres)=1.4e-08
# it=5 var=1.09e+00
#    -1.18e+00<=UPDATE<=-1.10e-01, deltat=1.00e-01
# ierr=0 avg_it=0073 max(res)=9.9e-09 max(pres)=1.4e-08
# it=6 var=1.08e+00
#    -1.06e+00<=UPDATE<=-5.74e-02, deltat=1.00e-01
# ierr=0 avg_it=0074 max(res)=9.0e-09 max(pres)=1.3e-08
# it=7 var=1.07e+00
#    -9.57e-01<=UPDATE<=4.16e-03, deltat=1.00e-01
# ierr=0 avg_it=0074 max(res)=9.2e-09 max(pres)=1.3e-08
# it=8 var=1.07e+00
#    -8.61e-01<=UPDATE<=5.41e-02, deltat=1.00e-01
# ierr=0 avg_it=0074 max(res)=9.7e-09 max(pres)=1.4e-08
# it=9 var=1.06e+00
#    -7.75e-01<=UPDATE<=9.27e-02, deltat=1.00e-01
# ierr=0 avg_it=0074 max(res)=1.0e-08 max(pres)=1.4e-08
# it=10 var=1.04e+00
#    -6.97e-01<=UPDATE<=1.22e-01, deltat=1.00e-01
# ierr=0 avg_it=0074 max(res)=8.8e-09 max(pres)=1.3e-08
# it=11 var=1.03e+00
#    -6.28e-01<=UPDATE<=1.42e-01, deltat=1.00e-01
# ierr=0 avg_it=0074 max(res)=9.7e-09 max(pres)=1.4e-08
# it=12 var=1.02e+00
#    -5.65e-01<=UPDATE<=1.56e-01, deltat=1.00e-01
# ierr=0 avg_it=0074 max(res)=9.9e-09 max(pres)=1.4e-08
# it=13 var=9.96e-01
#    -5.08e-01<=UPDATE<=1.65e-01, deltat=1.00e-01
# ierr=0 avg_it=0074 max(res)=9.8e-09 max(pres)=1.4e-08
# it=14 var=9.75e-01
#    -4.58e-01<=UPDATE<=1.84e-01, deltat=1.00e-01
# ierr=0 avg_it=0074 max(res)=9.8e-09 max(pres)=1.4e-08
# it=15 var=9.50e-01
#    -4.13e-01<=UPDATE<=2.41e-01, deltat=1.00e-01
# ierr=0 avg_it=0074 max(res)=9.9e-09 max(pres)=1.4e-08
# it=16 var=9.21e-01
#    -3.72e-01<=UPDATE<=2.86e-01, deltat=1.00e-01
# ierr=0 avg_it=0074 max(res)=9.8e-09 max(pres)=1.4e-08
# it=17 var=8.89e-01
#    -3.36e-01<=UPDATE<=3.20e-01, deltat=1.00e-01
# ierr=0 avg_it=0075 max(res)=1.0e-08 max(pres)=1.4e-08
# it=18 var=8.53e-01
#    -3.03e-01<=UPDATE<=3.44e-01, deltat=1.00e-01
# ierr=0 avg_it=0075 max(res)=9.9e-09 max(pres)=1.4e-08
# it=19 var=8.14e-01
#    -2.73e-01<=UPDATE<=3.60e-01, deltat=1.00e-01
# ierr=0 avg_it=0075 max(res)=9.7e-09 max(pres)=1.4e-08
# it=20 var=7.72e-01
#    -2.47e-01<=UPDATE<=3.68e-01, deltat=1.00e-01
# ierr=0 avg_it=0075 max(res)=9.5e-09 max(pres)=1.3e-08
# it=21 var=7.28e-01
#    -2.24e-01<=UPDATE<=3.71e-01, deltat=1.00e-01
# ierr=0 avg_it=0076 max(res)=1.0e-08 max(pres)=1.4e-08
# it=22 var=6.82e-01
#    -2.04e-01<=UPDATE<=3.81e-01, deltat=1.00e-01
# ierr=0 avg_it=0076 max(res)=9.9e-09 max(pres)=1.4e-08
# it=23 var=6.36e-01
#    -1.92e-01<=UPDATE<=4.07e-01, deltat=1.00e-01
# ierr=0 avg_it=0076 max(res)=9.6e-09 max(pres)=1.4e-08
# it=24 var=5.91e-01
#    -1.94e-01<=UPDATE<=4.25e-01, deltat=1.00e-01
# ierr=0 avg_it=0076 max(res)=9.9e-09 max(pres)=1.4e-08
# it=25 var=5.46e-01
#    -1.95e-01<=UPDATE<=4.35e-01, deltat=1.00e-01
# ierr=0 avg_it=0077 max(res)=9.7e-09 max(pres)=1.4e-08
# it=26 var=5.04e-01
#    -1.96e-01<=UPDATE<=4.37e-01, deltat=1.00e-01
# ierr=0 avg_it=0076 max(res)=9.9e-09 max(pres)=1.4e-08
# it=27 var=4.64e-01
#    -1.97e-01<=UPDATE<=4.34e-01, deltat=1.00e-01
# ierr=0 avg_it=0076 max(res)=1.0e-08 max(pres)=1.4e-08
# it=28 var=4.26e-01
#    -1.96e-01<=UPDATE<=4.24e-01, deltat=1.00e-01
# ierr=0 avg_it=0076 max(res)=9.9e-09 max(pres)=1.4e-08
# it=29 var=3.92e-01
#    -1.95e-01<=UPDATE<=4.10e-01, deltat=1.00e-01
# ierr=0 avg_it=0075 max(res)=1.0e-08 max(pres)=1.4e-08
# it=30 var=3.60e-01
# Optimal Energy is 9.974513935502774 | Current Energy is 3.4371883144499473
# MinNorm Setup: n_row: 354, n_col: 1007, self.n_rhs: 30
# init signature: (self, tol_optimization=0.001, tol_constraint=1e-08, method='explicit_tdens', max_iter=200, max_restart=5, method_ctrl=None, verbose=0, log=0, log_file='admk.log', beta=1, log_print: bool = True)
# ierr=0 avg_it=0050 max(res)=9.4e-09 max(pres)=1.3e-08
#    -2.00e+00<=UPDATE<=-7.39e-01, deltat=1.00e-01
# ierr=0 avg_it=0049 max(res)=9.7e-09 max(pres)=1.4e-08
# it=1 var=1.10e+00
#    -1.80e+00<=UPDATE<=-6.02e-01, deltat=1.00e-01
# ierr=0 avg_it=0049 max(res)=9.5e-09 max(pres)=1.3e-08
# it=2 var=1.10e+00
#    -1.62e+00<=UPDATE<=-4.82e-01, deltat=1.00e-01
# ierr=0 avg_it=0048 max(res)=9.8e-09 max(pres)=1.4e-08
# it=3 var=1.10e+00
#    -1.46e+00<=UPDATE<=-3.79e-01, deltat=1.00e-01
# ierr=0 avg_it=0048 max(res)=9.7e-09 max(pres)=1.4e-08
# it=4 var=1.09e+00
#    -1.31e+00<=UPDATE<=-2.91e-01, deltat=1.00e-01
# ierr=0 avg_it=0048 max(res)=9.8e-09 max(pres)=1.4e-08
# it=5 var=1.09e+00
#    -1.18e+00<=UPDATE<=-2.16e-01, deltat=1.00e-01
# ierr=0 avg_it=0047 max(res)=8.7e-09 max(pres)=1.2e-08
# it=6 var=1.08e+00
#    -1.06e+00<=UPDATE<=-1.55e-01, deltat=1.00e-01
# ierr=0 avg_it=0047 max(res)=9.9e-09 max(pres)=1.4e-08
# it=7 var=1.08e+00
#    -9.57e-01<=UPDATE<=-1.04e-01, deltat=1.00e-01
# ierr=0 avg_it=0047 max(res)=9.9e-09 max(pres)=1.4e-08
# it=8 var=1.07e+00
#    -8.61e-01<=UPDATE<=-6.10e-02, deltat=1.00e-01
# ierr=0 avg_it=0047 max(res)=9.5e-09 max(pres)=1.3e-08
# it=9 var=1.06e+00
#    -7.75e-01<=UPDATE<=-1.40e-02, deltat=1.00e-01
# ierr=0 avg_it=0047 max(res)=9.3e-09 max(pres)=1.3e-08
# it=10 var=1.06e+00
#    -6.97e-01<=UPDATE<=2.16e-02, deltat=1.00e-01
# ierr=0 avg_it=0047 max(res)=8.7e-09 max(pres)=1.2e-08
# it=11 var=1.04e+00
#    -6.28e-01<=UPDATE<=4.75e-02, deltat=1.00e-01
# ierr=0 avg_it=0047 max(res)=8.9e-09 max(pres)=1.3e-08
# it=12 var=1.03e+00
#    -5.65e-01<=UPDATE<=6.52e-02, deltat=1.00e-01
# ierr=0 avg_it=0047 max(res)=9.5e-09 max(pres)=1.3e-08
# it=13 var=1.01e+00
#    -5.08e-01<=UPDATE<=7.61e-02, deltat=1.00e-01
# ierr=0 avg_it=0047 max(res)=9.0e-09 max(pres)=1.3e-08
# it=14 var=9.96e-01
#    -4.58e-01<=UPDATE<=8.15e-02, deltat=1.00e-01
# ierr=0 avg_it=0046 max(res)=9.2e-09 max(pres)=1.3e-08
# it=15 var=9.75e-01
#    -4.13e-01<=UPDATE<=8.28e-02, deltat=1.00e-01
# ierr=0 avg_it=0047 max(res)=1.0e-08 max(pres)=1.4e-08
# it=16 var=9.50e-01
#    -3.72e-01<=UPDATE<=8.11e-02, deltat=1.00e-01
# ierr=0 avg_it=0046 max(res)=9.4e-09 max(pres)=1.3e-08
# it=17 var=9.22e-01
#    -3.35e-01<=UPDATE<=1.31e-01, deltat=1.00e-01
# ierr=0 avg_it=0046 max(res)=9.3e-09 max(pres)=1.3e-08
# it=18 var=8.91e-01
#    -3.02e-01<=UPDATE<=1.83e-01, deltat=1.00e-01
# ierr=0 avg_it=0046 max(res)=9.6e-09 max(pres)=1.4e-08
# it=19 var=8.56e-01
#    -2.72e-01<=UPDATE<=2.28e-01, deltat=1.00e-01
# ierr=0 avg_it=0046 max(res)=9.8e-09 max(pres)=1.4e-08
# it=20 var=8.18e-01
#    -2.46e-01<=UPDATE<=2.66e-01, deltat=1.00e-01
# ierr=0 avg_it=0046 max(res)=8.8e-09 max(pres)=1.3e-08
# it=21 var=7.78e-01
#    -2.24e-01<=UPDATE<=2.97e-01, deltat=1.00e-01
# ierr=0 avg_it=0046 max(res)=1.0e-08 max(pres)=1.4e-08
# it=22 var=7.35e-01
#    -2.05e-01<=UPDATE<=3.22e-01, deltat=1.00e-01
# ierr=0 avg_it=0046 max(res)=9.6e-09 max(pres)=1.4e-08
# it=23 var=6.90e-01
#    -1.91e-01<=UPDATE<=3.40e-01, deltat=1.00e-01
# ierr=0 avg_it=0045 max(res)=9.9e-09 max(pres)=1.4e-08
# it=24 var=6.45e-01
#    -1.90e-01<=UPDATE<=3.53e-01, deltat=1.00e-01
# ierr=0 avg_it=0045 max(res)=9.5e-09 max(pres)=1.3e-08
# it=25 var=6.00e-01
#    -1.89e-01<=UPDATE<=3.62e-01, deltat=1.00e-01
# ierr=0 avg_it=0045 max(res)=9.4e-09 max(pres)=1.3e-08
# it=26 var=5.55e-01
#    -1.88e-01<=UPDATE<=3.66e-01, deltat=1.00e-01
# ierr=0 avg_it=0045 max(res)=9.8e-09 max(pres)=1.4e-08
# it=27 var=5.13e-01
#    -1.86e-01<=UPDATE<=3.67e-01, deltat=1.00e-01
# ierr=0 avg_it=0045 max(res)=9.7e-09 max(pres)=1.4e-08
# it=28 var=4.72e-01
#    -1.84e-01<=UPDATE<=3.64e-01, deltat=1.00e-01
# ierr=0 avg_it=0045 max(res)=9.7e-09 max(pres)=1.4e-08
# it=29 var=4.34e-01
#    -1.82e-01<=UPDATE<=3.59e-01, deltat=1.00e-01
# ierr=0 avg_it=0044 max(res)=9.8e-09 max(pres)=1.4e-08
# it=30 var=3.98e-01
# Optimal Energy is 9.974513935502774 | Current Energy is 3.4371883144499473
